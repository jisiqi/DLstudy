# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

#载入数据集
mnist = input_data.read_data_sets("MNIST_data",one_hot=True)

# 每个批次的大小
batch_size = 50
#批次的个数
n_batch = mnist.train.num_examples // batch_size

# 定义placeholder
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])
keep_prob = tf.placeholder(tf.float32)


#创建一个简单的神经网络
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev=0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000,1000],stddev=0.1))
b3 = tf.Variable(tf.zeros([1000])+0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)

prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)

# 二次代价函数
#loss = tf.reduce_mean(tf.square(y - prediction))


#交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))


# 使用梯度下降法进行训练
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#变量初始化
init = tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(31):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:0.7})
            
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        print("Iter" + str(epoch) + "test accuracy" + str(test_acc) + "training accuracy" + str(train_acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0test accuracy0.9233training accuracy0.92036366
# Iter1test accuracy0.9286training accuracy0.9278182
# Iter2test accuracy0.9383training accuracy0.93863636
# Iter3test accuracy0.945training accuracy0.94632727
# Iter4test accuracy0.9487training accuracy0.9503273
# Iter5test accuracy0.9526training accuracy0.95445454
# Iter6test accuracy0.9537training accuracy0.9579091
# Iter7test accuracy0.9546training accuracy0.95925456
# Iter8test accuracy0.9564training accuracy0.961
# Iter9test accuracy0.9587training accuracy0.9631818
# Iter10test accuracy0.9612training accuracy0.96614546
# Iter11test accuracy0.9611training accuracy0.9662182
# Iter12test accuracy0.9622training accuracy0.9683091
# Iter13test accuracy0.9652training accuracy0.96936363
# ...

# %%
#无DP
Iter0test accuracy0.9485training accuracy0.95594543
Iter1test accuracy0.9641training accuracy0.9752
Iter2test accuracy0.9699training accuracy0.98367274
Iter3test accuracy0.9709training accuracy0.98774546
Iter4test accuracy0.9734training accuracy0.9904182
Iter5test accuracy0.9736training accuracy0.9921273
Iter6test accuracy0.9743training accuracy0.9932909
Iter7test accuracy0.9756training accuracy0.99398184
Iter8test accuracy0.9753training accuracy0.99438184
Iter9test accuracy0.9761training accuracy0.9948364
Iter10test accuracy0.9769training accuracy0.9950727
Iter11test accuracy0.9759training accuracy0.99529094
Iter12test accuracy0.9758training accuracy0.9954727
Iter13test accuracy0.9755training accuracy0.99561816
Iter14test accuracy0.9756training accuracy0.99570906
Iter15test accuracy0.9759training accuracy0.9958909
Iter16test accuracy0.9756training accuracy0.9960909
Iter17test accuracy0.9759training accuracy0.9962364
Iter18test accuracy0.9762training accuracy0.99625456
Iter19test accuracy0.9767training accuracy0.9963818
Iter20test accuracy0.9767training accuracy0.99643636
Iter21test accuracy0.9768training accuracy0.99652725
Iter22test accuracy0.9774training accuracy0.9966364
Iter23test accuracy0.9769training accuracy0.9967091
Iter24test accuracy0.977training accuracy0.99676365
Iter25test accuracy0.9771training accuracy0.9967818
Iter26test accuracy0.9766training accuracy0.99683636
Iter27test accuracy0.9767training accuracy0.9968727
Iter28test accuracy0.9765training accuracy0.9969091
Iter29test accuracy0.9769training accuracy0.9969636
Iter30test accuracy0.9769training accuracy0.9969636
# Out:
#   File "<ipython-input-9-3a774b4fbab1>", line 2
#     Iter0test accuracy0.9485training accuracy0.95594543
#                       ^
# SyntaxError: invalid syntax

# %%
#有DP
    
Iter0test accuracy0.9233training accuracy0.92036366
Iter1test accuracy0.9286training accuracy0.9278182
Iter2test accuracy0.9383training accuracy0.93863636
Iter3test accuracy0.945training accuracy0.94632727
Iter4test accuracy0.9487training accuracy0.9503273
Iter5test accuracy0.9526training accuracy0.95445454
Iter6test accuracy0.9537training accuracy0.9579091
Iter7test accuracy0.9546training accuracy0.95925456
Iter8test accuracy0.9564training accuracy0.961
Iter9test accuracy0.9587training accuracy0.9631818
Iter10test accuracy0.9612training accuracy0.96614546
Iter11test accuracy0.9611training accuracy0.9662182
Iter12test accuracy0.9622training accuracy0.9683091
Iter13test accuracy0.9652training accuracy0.96936363
Iter14test accuracy0.9636training accuracy0.9688909
Iter15test accuracy0.9662training accuracy0.97156364
Iter16test accuracy0.9669training accuracy0.97263634
Iter17test accuracy0.9663training accuracy0.9731454
Iter18test accuracy0.9684training accuracy0.9748909
Iter19test accuracy0.9684training accuracy0.97496367
Iter20test accuracy0.9694training accuracy0.9757636
Iter21test accuracy0.9693training accuracy0.97614545
Iter22test accuracy0.9703training accuracy0.97678185
Iter23test accuracy0.97training accuracy0.9773273
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-25a367b1c700> in <module>
# ----> 1 tf.zeros([2000]+0.1)
#
# TypeError: can only concatenate list (not "float") to list
