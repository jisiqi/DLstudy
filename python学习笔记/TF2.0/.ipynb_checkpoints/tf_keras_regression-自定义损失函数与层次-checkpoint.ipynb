# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os 
import sys
import time
import tensorflow as tf
from tensorflow import keras
# Out:
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# F:\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
#分割数据集为：0.7训练集，0.1验证集，0.2测试集

from sklearn.model_selection import train_test_split

x_train_all,x_test,y_train_all,y_test = train_test_split(
        housing.data,
        housing.target,
        random_state = 7,
        test_size=0.2)

x_train,x_valid,y_train,y_valid = train_test_split(
        x_train_all,
        y_train_all,
        random_state=11,
        test_size=0.125)

print(x_train.shape,y_train.shape)
print(x_valid.shape,y_valid.shape)
print(x_test.shape,y_test.shape)
# Out:
# (14448, 8) (14448,)
# (2064, 8) (2064,)
# (4128, 8) (4128,)

# %%
#归一化操作  x = (s-u)/std   减去均值，除以方差

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


x_train_scaler = scaler.fit_transform(x_train)
x_valid_scaler = scaler.transform(x_valid)
x_test_scaler = scaler.transform(x_test)

# %%
#tf.keras.models.Sequential

model = keras.models.Sequential([
    
    keras.layers.Dense(30, activation="relu", input_shape = x_train.shape[1:]),
    keras.layers.Dense(1)
])


model.summary()
model.compile(loss="mean_squared_error",
             optimizer="sgd",
             metrics=["accuracy"])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 30)                270
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaler, y_train, epochs = 100,
                   validation_data=(x_valid_scaler,y_valid),
                   
                   callbacks = [keras.callbacks.EarlyStopping(patience=5,min_delta=1e-3)]
                   )
# Out:
# Train on 14448 samples, validate on 2064 samples
# Epoch 1/100
# 14448/14448 [==============================] - 0s 30us/sample - loss: 1.0273 - accuracy: 0.0027 - val_loss: 0.4850 - val_accuracy: 0.0039
# Epoch 2/100
# 14448/14448 [==============================] - 0s 25us/sample - loss: 0.4930 - accuracy: 0.0028 - val_loss: 0.4329 - val_accuracy: 0.0039
# Epoch 3/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.4464 - accuracy: 0.0028 - val_loss: 0.4133 - val_accuracy: 0.0039
# Epoch 4/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.4335 - accuracy: 0.0028 - val_loss: 0.3978 - val_accuracy: 0.0039
# Epoch 5/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.4012 - accuracy: 0.0028 - val_loss: 0.3879 - val_accuracy: 0.0039
# Epoch 6/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3950 - accuracy: 0.0028 - val_loss: 0.3825 - val_accuracy: 0.0039
# Epoch 7/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3866 - accuracy: 0.0028 - val_loss: 0.3809 - val_accuracy: 0.0039
# Epoch 8/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3805 - accuracy: 0.0028 - val_loss: 0.3745 - val_accuracy: 0.0039
# Epoch 9/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3788 - accuracy: 0.0028 - val_loss: 0.3715 - val_accuracy: 0.0039
# Epoch 10/100
# 14448/14448 [==============================] - 0s 28us/sample - loss: 0.3725 - accuracy: 0.0028 - val_loss: 0.3679 - val_accuracy: 0.0039
# Epoch 11/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3770 - accuracy: 0.0028 - val_loss: 0.3722 - val_accuracy: 0.0039
# Epoch 12/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3687 - accuracy: 0.0028 - val_loss: 0.3648 - val_accuracy: 0.0039
# Epoch 13/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3655 - accuracy: 0.0028 - val_loss: 0.3654 - val_accuracy: 0.0039
# Epoch 14/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3616 - accuracy: 0.0028 - val_loss: 0.3617 - val_accuracy: 0.0039
# Epoch 15/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3584 - accuracy: 0.0028 - val_loss: 0.3583 - val_accuracy: 0.0039
# Epoch 16/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3576 - accuracy: 0.0028 - val_loss: 0.3625 - val_accuracy: 0.0039
# Epoch 17/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3544 - accuracy: 0.0028 - val_loss: 0.3719 - val_accuracy: 0.0039
# Epoch 18/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3515 - accuracy: 0.0028 - val_loss: 0.3544 - val_accuracy: 0.0039
# Epoch 19/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3481 - accuracy: 0.0028 - val_loss: 0.3535 - val_accuracy: 0.0039
# Epoch 20/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3614 - accuracy: 0.0028 - val_loss: 0.3500 - val_accuracy: 0.0039
# Epoch 21/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3437 - accuracy: 0.0028 - val_loss: 0.3517 - val_accuracy: 0.0039
# Epoch 22/100
# 14448/14448 [==============================] - 0s 25us/sample - loss: 0.3417 - accuracy: 0.0028 - val_loss: 0.3473 - val_accuracy: 0.0034
# Epoch 23/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3495 - accuracy: 0.0028 - val_loss: 0.3484 - val_accuracy: 0.0039
# Epoch 24/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3629 - accuracy: 0.0028 - val_loss: 0.3489 - val_accuracy: 0.0034
# Epoch 25/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3373 - accuracy: 0.0028 - val_loss: 0.3455 - val_accuracy: 0.0034
# Epoch 26/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3430 - accuracy: 0.0028 - val_loss: 0.3442 - val_accuracy: 0.0034
# Epoch 27/100
# 14448/14448 [==============================] - 0s 30us/sample - loss: 0.3451 - accuracy: 0.0028 - val_loss: 0.3508 - val_accuracy: 0.0034
# Epoch 28/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3357 - accuracy: 0.0028 - val_loss: 0.3441 - val_accuracy: 0.0034
# Epoch 29/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3337 - accuracy: 0.0028 - val_loss: 0.3415 - val_accuracy: 0.0034
# Epoch 30/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3356 - accuracy: 0.0028 - val_loss: 0.3402 - val_accuracy: 0.0034
# Epoch 31/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3307 - accuracy: 0.0028 - val_loss: 0.3394 - val_accuracy: 0.0034
# Epoch 32/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3304 - accuracy: 0.0028 - val_loss: 0.3386 - val_accuracy: 0.0039
# Epoch 33/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3279 - accuracy: 0.0028 - val_loss: 0.3410 - val_accuracy: 0.0034
# Epoch 34/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3320 - accuracy: 0.0028 - val_loss: 0.3372 - val_accuracy: 0.0034
# Epoch 35/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3256 - accuracy: 0.0028 - val_loss: 0.3350 - val_accuracy: 0.0034
# Epoch 36/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3257 - accuracy: 0.0028 - val_loss: 0.3328 - val_accuracy: 0.0034
# Epoch 37/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3260 - accuracy: 0.0028 - val_loss: 0.3326 - val_accuracy: 0.0034
# Epoch 38/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3257 - accuracy: 0.0028 - val_loss: 0.3320 - val_accuracy: 0.0034
# Epoch 39/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3253 - accuracy: 0.0028 - val_loss: 0.3331 - val_accuracy: 0.0034
# Epoch 40/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3247 - accuracy: 0.0028 - val_loss: 0.3335 - val_accuracy: 0.0034
# Epoch 41/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3230 - accuracy: 0.0028 - val_loss: 0.3304 - val_accuracy: 0.0034
# Epoch 42/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3228 - accuracy: 0.0028 - val_loss: 0.3333 - val_accuracy: 0.0034
# Epoch 43/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3216 - accuracy: 0.0028 - val_loss: 0.3315 - val_accuracy: 0.0034
# Epoch 44/100
# 14448/14448 [==============================] - 0s 29us/sample - loss: 0.3199 - accuracy: 0.0028 - val_loss: 0.3281 - val_accuracy: 0.0034
# Epoch 45/100
# 14448/14448 [==============================] - 0s 24us/sample - loss: 0.3174 - accuracy: 0.0027 - val_loss: 0.3290 - val_accuracy: 0.0034
# Epoch 46/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3187 - accuracy: 0.0028 - val_loss: 0.3270 - val_accuracy: 0.0034
# Epoch 47/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3165 - accuracy: 0.0028 - val_loss: 0.3257 - val_accuracy: 0.0034
# Epoch 48/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3167 - accuracy: 0.0028 - val_loss: 0.3299 - val_accuracy: 0.0039
# Epoch 49/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3169 - accuracy: 0.0028 - val_loss: 0.3282 - val_accuracy: 0.0034
# Epoch 50/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3223 - accuracy: 0.0028 - val_loss: 0.3222 - val_accuracy: 0.0039
# Epoch 51/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3178 - accuracy: 0.0028 - val_loss: 0.3220 - val_accuracy: 0.0034
# Epoch 52/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3156 - accuracy: 0.0028 - val_loss: 0.3211 - val_accuracy: 0.0039
# Epoch 53/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3137 - accuracy: 0.0027 - val_loss: 0.3222 - val_accuracy: 0.0034
# Epoch 54/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3142 - accuracy: 0.0027 - val_loss: 0.3241 - val_accuracy: 0.0034
# Epoch 55/100
# 14448/14448 [==============================] - 0s 21us/sample - loss: 0.3118 - accuracy: 0.0028 - val_loss: 0.3176 - val_accuracy: 0.0034
# Epoch 56/100
# 14448/14448 [==============================] - 0s 22us/sample - loss: 0.3144 - accuracy: 0.0028 - val_loss: 0.3220 - val_accuracy: 0.0034
# Epoch 57/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3117 - accuracy: 0.0028 - val_loss: 0.3237 - val_accuracy: 0.0039
# Epoch 58/100
# 14448/14448 [==============================] - 0s 23us/sample - loss: 0.3126 - accuracy: 0.0028 - val_loss: 0.3291 - val_accuracy: 0.0034
# Epoch 59/100
# 14448/14448 [==============================] - 0s 28us/sample - loss: 0.3132 - accuracy: 0.0028 - val_loss: 0.3215 - val_accuracy: 0.0034
# Epoch 60/100
# 14448/14448 [==============================] - 0s 29us/sample - loss: 0.3102 - accuracy: 0.0028 - val_loss: 0.3185 - val_accuracy: 0.0034
