# %% [markdown]
# ![](./graphs/dl_banner.jpg)

# %% [markdown]
# # 用tensorflow low level API构建循环神经网络
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %% [markdown]
# ## 0.知识背景：循环神经网络
# 循环神经网络或RNN是一类用于处理序列数据的神经网络，典型的时间序列数据场景是文本，RNN在自然语言处理中发挥着很大的作用。循环神经网络会对序列的每个时间点数据处理，典型结构如下。
# ![RNN](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-unrolled.png)
#
# 循环神经网络中最常用到的两个变种结构为LSTM和GRU，它们在对数据计算的cell结构上做了一些调整，分别如下：
# ![LSTM](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-chain.png)
# ![GRU](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-var-GRU.png)
#
# ## 0.问题背景：MNIST 手写数字
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)
#
# 这是一个非常经典的问题，我们的对象是手写数字图片，我们需要根据手写数字图片的输入，构建线性的分类器(softmax分类器)去区分图片是手写数字0-9中的哪一个。这个问题的数据集，每一张图片的表示是长宽为28的矩阵，我们有时候会把它展开成784维的向量。MNIST手写数据集长成下面这样。
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)
#
# 更多的信息可以参考: http://yann.lecun.com/exdb/mnist/

# %% [markdown]
# ## 1.引入工具库

# %%
from __future__ import division, print_function, absolute_import
import tensorflow as tf
from tensorflow.contrib import rnn
import matplotlib.pyplot as plt
import numpy as np
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
session = tf.Session(config=config)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2.设定超参数
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
# 训练超参数
learning_rate = 0.001
training_steps = 10000
batch_size = 128
display_step = 10

# 神经网络超参数
num_input = 28 # MNIST数据输入(数据形状: 28*28)，一个时间点上输入28个值
timesteps = 28 # 总共会有28个timestep
num_hidden = 128 # 神经元个数
num_classes = 10 # MNIST总共类别(0-9总共10个手写数字)


# 占位符
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# 变量
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %% [markdown]
# ## 3.准备数据

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/data/Deep_learning/MNIST_data", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-c7fb4c30fcf0>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /data/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /data/MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /data/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /data/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## 4.构建模型
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
def RNN(x, weights, biases):

    # RNN是时间序列型网络结构，我们需要按照它的形式去组织数据
    # 我们把数据组织成这样的形式: (batch_size, timesteps, n_input)
    # 也就是说一批样本batch_size个样本，总共会以timesteps个长度为n_input的向量形式送入

    # 为了得到timesteps个(batch_size, n_input)形态的输入
    x = tf.unstack(x, timesteps, 1)

    # 定义RNN中单个cell的格式
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # 用cell串成LSTM网络
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # 结果要通过全连接层
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %% [markdown]
# ## 5.计算损失与优化
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
# 构建RNN网络进行预估
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# 定义损失计算方法与优化器
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# 评估模型
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# 初始化变量
init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-5-a5b2abdbc768>:11: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').
# WARNING:tensorflow:From <ipython-input-6-9d9109d910db>:7: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %% [markdown]
# ## 6.在session当中完成计算图计算(损失计算与优化、参数更新迭代)
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
# 在session当中开始训练
with tf.Session() as sess:

    # 初始化
    sess.run(init)

    for step in range(1, training_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        batch_x = batch_x.reshape((batch_size, timesteps, num_input))
        # 优化
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
        if step % display_step == 0 or step == 1:
            # 计算准确率
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y})
            print("第" + str(step) + "步, 一个minibatch上的损失为 " + \
                  "{:.4f}".format(loss) + ", 训练准确率为 " + \
                  "{:.3f}".format(acc))

    print("完成训练！")

    # 计算准确率
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, timesteps, num_input))
    test_label = mnist.test.labels[:test_len]
    print("测试准确率为 ", \
        sess.run(accuracy, feed_dict={X: test_data, Y: test_label}))
# Out:
# 第1步, 一个minibatch上的损失为 2.6086, 训练准确率为 0.148
# 第10步, 一个minibatch上的损失为 2.5286, 训练准确率为 0.148
# 第20步, 一个minibatch上的损失为 2.4149, 训练准确率为 0.125
# 第30步, 一个minibatch上的损失为 2.4308, 训练准确率为 0.086
# 第40步, 一个minibatch上的损失为 2.4484, 训练准确率为 0.094
# 第50步, 一个minibatch上的损失为 2.3739, 训练准确率为 0.180
# 第60步, 一个minibatch上的损失为 2.2896, 训练准确率为 0.188
# 第70步, 一个minibatch上的损失为 2.1766, 训练准确率为 0.156
# 第80步, 一个minibatch上的损失为 2.1287, 训练准确率为 0.227
# 第90步, 一个minibatch上的损失为 2.1242, 训练准确率为 0.242
# 第100步, 一个minibatch上的损失为 2.2296, 训练准确率为 0.203
# 第110步, 一个minibatch上的损失为 2.1624, 训练准确率为 0.219
# 第120步, 一个minibatch上的损失为 2.1047, 训练准确率为 0.234
# 第130步, 一个minibatch上的损失为 2.1500, 训练准确率为 0.180
# 第140步, 一个minibatch上的损失为 2.0473, 训练准确率为 0.312
# 第150步, 一个minibatch上的损失为 2.1077, 训练准确率为 0.250
# 第160步, 一个minibatch上的损失为 2.0972, 训练准确率为 0.258
# 第170步, 一个minibatch上的损失为 2.0921, 训练准确率为 0.281
# 第180步, 一个minibatch上的损失为 2.0098, 训练准确率为 0.289
# 第190步, 一个minibatch上的损失为 1.9757, 训练准确率为 0.375
# 第200步, 一个minibatch上的损失为 2.0780, 训练准确率为 0.266
# 第210步, 一个minibatch上的损失为 2.0266, 训练准确率为 0.320
# 第220步, 一个minibatch上的损失为 1.9929, 训练准确率为 0.375
# 第230步, 一个minibatch上的损失为 1.9492, 训练准确率为 0.359
# 第240步, 一个minibatch上的损失为 2.0449, 训练准确率为 0.328
# 第250步, 一个minibatch上的损失为 1.9855, 训练准确率为 0.336
# 第260步, 一个minibatch上的损失为 1.9986, 训练准确率为 0.320
# 第270步, 一个minibatch上的损失为 2.0159, 训练准确率为 0.258
# 第280步, 一个minibatch上的损失为 2.0132, 训练准确率为 0.297
# 第290步, 一个minibatch上的损失为 1.9643, 训练准确率为 0.305
# 第300步, 一个minibatch上的损失为 1.9024, 训练准确率为 0.398
# 第310步, 一个minibatch上的损失为 1.9550, 训练准确率为 0.328
# 第320步, 一个minibatch上的损失为 1.9836, 训练准确率为 0.375
# 第330步, 一个minibatch上的损失为 1.9703, 训练准确率为 0.305
# 第340步, 一个minibatch上的损失为 1.9349, 训练准确率为 0.344
# 第350步, 一个minibatch上的损失为 1.8228, 训练准确率为 0.414
# 第360步, 一个minibatch上的损失为 1.9562, 训练准确率为 0.312
# 第370步, 一个minibatch上的损失为 1.7608, 训练准确率为 0.422
# 第380步, 一个minibatch上的损失为 1.8983, 训练准确率为 0.406
# 第390步, 一个minibatch上的损失为 1.9121, 训练准确率为 0.352
# 第400步, 一个minibatch上的损失为 1.7710, 训练准确率为 0.477
# 第410步, 一个minibatch上的损失为 1.9520, 训练准确率为 0.359
# 第420步, 一个minibatch上的损失为 1.8792, 训练准确率为 0.352
# 第430步, 一个minibatch上的损失为 1.8264, 训练准确率为 0.383
# 第440步, 一个minibatch上的损失为 1.8525, 训练准确率为 0.391
# 第450步, 一个minibatch上的损失为 1.8318, 训练准确率为 0.422
# 第460步, 一个minibatch上的损失为 1.9241, 训练准确率为 0.383
# 第470步, 一个minibatch上的损失为 1.8368, 训练准确率为 0.438
# 第480步, 一个minibatch上的损失为 1.8464, 训练准确率为 0.352
# 第490步, 一个minibatch上的损失为 1.8164, 训练准确率为 0.391
# 第500步, 一个minibatch上的损失为 1.8347, 训练准确率为 0.445
# 第510步, 一个minibatch上的损失为 1.7791, 训练准确率为 0.430
# 第520步, 一个minibatch上的损失为 1.6940, 训练准确率为 0.461
# 第530步, 一个minibatch上的损失为 1.7423, 训练准确率为 0.414
# 第540步, 一个minibatch上的损失为 1.8355, 训练准确率为 0.398
# 第550步, 一个minibatch上的损失为 1.7946, 训练准确率为 0.453
# 第560步, 一个minibatch上的损失为 1.7078, 训练准确率为 0.469
# 第570步, 一个minibatch上的损失为 1.8337, 训练准确率为 0.406
# 第580步, 一个minibatch上的损失为 1.7479, 训练准确率为 0.477
# 第590步, 一个minibatch上的损失为 1.8343, 训练准确率为 0.359
# 第600步, 一个minibatch上的损失为 1.6816, 训练准确率为 0.469
# 第610步, 一个minibatch上的损失为 1.7233, 训练准确率为 0.453
# 第620步, 一个minibatch上的损失为 1.6954, 训练准确率为 0.477
# 第630步, 一个minibatch上的损失为 1.7602, 训练准确率为 0.422
# 第640步, 一个minibatch上的损失为 1.8238, 训练准确率为 0.438
# 第650步, 一个minibatch上的损失为 1.7242, 训练准确率为 0.453
# 第660步, 一个minibatch上的损失为 1.7421, 训练准确率为 0.391
# 第670步, 一个minibatch上的损失为 1.7520, 训练准确率为 0.484
# 第680步, 一个minibatch上的损失为 1.8413, 训练准确率为 0.375
# 第690步, 一个minibatch上的损失为 1.7042, 训练准确率为 0.445
# 第700步, 一个minibatch上的损失为 1.6459, 训练准确率为 0.445
# 第710步, 一个minibatch上的损失为 1.6524, 训练准确率为 0.516
# 第720步, 一个minibatch上的损失为 1.6371, 训练准确率为 0.500
# 第730步, 一个minibatch上的损失为 1.6753, 训练准确率为 0.523
# 第740步, 一个minibatch上的损失为 1.8156, 训练准确率为 0.391
# 第750步, 一个minibatch上的损失为 1.7911, 训练准确率为 0.438
# 第760步, 一个minibatch上的损失为 1.6934, 训练准确率为 0.414
# 第770步, 一个minibatch上的损失为 1.6842, 训练准确率为 0.430
# 第780步, 一个minibatch上的损失为 1.6928, 训练准确率为 0.484
# 第790步, 一个minibatch上的损失为 1.7912, 训练准确率为 0.383
# 第800步, 一个minibatch上的损失为 1.6230, 训练准确率为 0.523
# 第810步, 一个minibatch上的损失为 1.6377, 训练准确率为 0.508
# 第820步, 一个minibatch上的损失为 1.6432, 训练准确率为 0.438
# 第830步, 一个minibatch上的损失为 1.6026, 训练准确率为 0.547
# 第840步, 一个minibatch上的损失为 1.6668, 训练准确率为 0.422
# 第850步, 一个minibatch上的损失为 1.6597, 训练准确率为 0.500
# 第860步, 一个minibatch上的损失为 1.6858, 训练准确率为 0.414
# 第870步, 一个minibatch上的损失为 1.7206, 训练准确率为 0.438
# 第880步, 一个minibatch上的损失为 1.7386, 训练准确率为 0.398
# 第890步, 一个minibatch上的损失为 1.5673, 训练准确率为 0.531
# 第900步, 一个minibatch上的损失为 1.6025, 训练准确率为 0.531
# 第910步, 一个minibatch上的损失为 1.6650, 训练准确率为 0.484
# 第920步, 一个minibatch上的损失为 1.5525, 训练准确率为 0.547
# 第930步, 一个minibatch上的损失为 1.5782, 训练准确率为 0.484
# 第940步, 一个minibatch上的损失为 1.7887, 训练准确率为 0.453
# 第950步, 一个minibatch上的损失为 1.6762, 训练准确率为 0.523
# 第960步, 一个minibatch上的损失为 1.5783, 训练准确率为 0.547
# 第970步, 一个minibatch上的损失为 1.5259, 训练准确率为 0.516
# 第980步, 一个minibatch上的损失为 1.6627, 训练准确率为 0.469
# 第990步, 一个minibatch上的损失为 1.6003, 训练准确率为 0.508
# 第1000步, 一个minibatch上的损失为 1.6147, 训练准确率为 0.531
# 第1010步, 一个minibatch上的损失为 1.6539, 训练准确率为 0.508
# 第1020步, 一个minibatch上的损失为 1.5962, 训练准确率为 0.523
# 第1030步, 一个minibatch上的损失为 1.2896, 训练准确率为 0.727
# 第1040步, 一个minibatch上的损失为 1.6215, 训练准确率为 0.516
# 第1050步, 一个minibatch上的损失为 1.5492, 训练准确率为 0.516
# 第1060步, 一个minibatch上的损失为 1.5161, 训练准确率为 0.516
# 第1070步, 一个minibatch上的损失为 1.5473, 训练准确率为 0.484
# 第1080步, 一个minibatch上的损失为 1.5651, 训练准确率为 0.484
# 第1090步, 一个minibatch上的损失为 1.5304, 训练准确率为 0.516
# 第1100步, 一个minibatch上的损失为 1.5173, 训练准确率为 0.562
# 第1110步, 一个minibatch上的损失为 1.5003, 训练准确率为 0.523
# 第1120步, 一个minibatch上的损失为 1.4648, 训练准确率为 0.586
# 第1130步, 一个minibatch上的损失为 1.5804, 训练准确率为 0.531
# 第1140步, 一个minibatch上的损失为 1.5932, 训练准确率为 0.477
# 第1150步, 一个minibatch上的损失为 1.5574, 训练准确率为 0.523
# 第1160步, 一个minibatch上的损失为 1.6374, 训练准确率为 0.477
# 第1170步, 一个minibatch上的损失为 1.6069, 训练准确率为 0.453
# 第1180步, 一个minibatch上的损失为 1.5718, 训练准确率为 0.508
# 第1190步, 一个minibatch上的损失为 1.4773, 训练准确率为 0.562
# 第1200步, 一个minibatch上的损失为 1.4952, 训练准确率为 0.523
# 第1210步, 一个minibatch上的损失为 1.4526, 训练准确率为 0.562
# 第1220步, 一个minibatch上的损失为 1.5488, 训练准确率为 0.477
# 第1230步, 一个minibatch上的损失为 1.5409, 训练准确率为 0.477
# 第1240步, 一个minibatch上的损失为 1.6064, 训练准确率为 0.469
# 第1250步, 一个minibatch上的损失为 1.5549, 训练准确率为 0.453
# 第1260步, 一个minibatch上的损失为 1.5133, 训练准确率为 0.500
# 第1270步, 一个minibatch上的损失为 1.4700, 训练准确率为 0.555
# 第1280步, 一个minibatch上的损失为 1.4828, 训练准确率为 0.555
# 第1290步, 一个minibatch上的损失为 1.5144, 训练准确率为 0.508
# 第1300步, 一个minibatch上的损失为 1.4484, 训练准确率为 0.562
# 第1310步, 一个minibatch上的损失为 1.4551, 训练准确率为 0.586
# 第1320步, 一个minibatch上的损失为 1.5942, 训练准确率为 0.500
# 第1330步, 一个minibatch上的损失为 1.5755, 训练准确率为 0.461
# 第1340步, 一个minibatch上的损失为 1.4329, 训练准确率为 0.539
# 第1350步, 一个minibatch上的损失为 1.4688, 训练准确率为 0.531
# 第1360步, 一个minibatch上的损失为 1.5232, 训练准确率为 0.484
# 第1370步, 一个minibatch上的损失为 1.4583, 训练准确率为 0.594
# 第1380步, 一个minibatch上的损失为 1.4995, 训练准确率为 0.523
# 第1390步, 一个minibatch上的损失为 1.5222, 训练准确率为 0.523
# 第1400步, 一个minibatch上的损失为 1.4247, 训练准确率为 0.547
# 第1410步, 一个minibatch上的损失为 1.4788, 训练准确率为 0.539
# 第1420步, 一个minibatch上的损失为 1.4245, 训练准确率为 0.578
# 第1430步, 一个minibatch上的损失为 1.3019, 训练准确率为 0.641
# 第1440步, 一个minibatch上的损失为 1.3643, 训练准确率为 0.578
# 第1450步, 一个minibatch上的损失为 1.4324, 训练准确率为 0.555
# 第1460步, 一个minibatch上的损失为 1.4068, 训练准确率为 0.555
# 第1470步, 一个minibatch上的损失为 1.4794, 训练准确率为 0.547
# 第1480步, 一个minibatch上的损失为 1.4071, 训练准确率为 0.531
# 第1490步, 一个minibatch上的损失为 1.4659, 训练准确率为 0.539
# 第1500步, 一个minibatch上的损失为 1.4441, 训练准确率为 0.539
# 第1510步, 一个minibatch上的损失为 1.4484, 训练准确率为 0.484
# 第1520步, 一个minibatch上的损失为 1.5026, 训练准确率为 0.547
# 第1530步, 一个minibatch上的损失为 1.4587, 训练准确率为 0.523
# 第1540步, 一个minibatch上的损失为 1.5323, 训练准确率为 0.531
# 第1550步, 一个minibatch上的损失为 1.5568, 训练准确率为 0.500
# 第1560步, 一个minibatch上的损失为 1.3691, 训练准确率为 0.562
# 第1570步, 一个minibatch上的损失为 1.5106, 训练准确率为 0.477
# 第1580步, 一个minibatch上的损失为 1.5005, 训练准确率为 0.562
# 第1590步, 一个minibatch上的损失为 1.4064, 训练准确率为 0.539
# 第1600步, 一个minibatch上的损失为 1.5232, 训练准确率为 0.445
# 第1610步, 一个minibatch上的损失为 1.4745, 训练准确率为 0.508
# 第1620步, 一个minibatch上的损失为 1.3976, 训练准确率为 0.547
# 第1630步, 一个minibatch上的损失为 1.4903, 训练准确率为 0.477
# 第1640步, 一个minibatch上的损失为 1.3564, 训练准确率为 0.578
# 第1650步, 一个minibatch上的损失为 1.4795, 训练准确率为 0.547
# 第1660步, 一个minibatch上的损失为 1.4865, 训练准确率为 0.508
# 第1670步, 一个minibatch上的损失为 1.5924, 训练准确率为 0.523
# 第1680步, 一个minibatch上的损失为 1.3667, 训练准确率为 0.547
# 第1690步, 一个minibatch上的损失为 1.3823, 训练准确率为 0.531
# 第1700步, 一个minibatch上的损失为 1.2865, 训练准确率为 0.625
# 第1710步, 一个minibatch上的损失为 1.2542, 训练准确率为 0.625
# 第1720步, 一个minibatch上的损失为 1.5508, 训练准确率为 0.547
# 第1730步, 一个minibatch上的损失为 1.4854, 训练准确率为 0.523
# 第1740步, 一个minibatch上的损失为 1.3489, 训练准确率为 0.594
# 第1750步, 一个minibatch上的损失为 1.4539, 训练准确率为 0.539
# 第1760步, 一个minibatch上的损失为 1.3170, 训练准确率为 0.641
# 第1770步, 一个minibatch上的损失为 1.3869, 训练准确率为 0.555
# 第1780步, 一个minibatch上的损失为 1.4407, 训练准确率为 0.555
# 第1790步, 一个minibatch上的损失为 1.3234, 训练准确率为 0.602
# 第1800步, 一个minibatch上的损失为 1.4515, 训练准确率为 0.531
# 第1810步, 一个minibatch上的损失为 1.3487, 训练准确率为 0.562
# 第1820步, 一个minibatch上的损失为 1.3043, 训练准确率为 0.609
# 第1830步, 一个minibatch上的损失为 1.4180, 训练准确率为 0.523
# 第1840步, 一个minibatch上的损失为 1.3675, 训练准确率为 0.555
# 第1850步, 一个minibatch上的损失为 1.3210, 训练准确率为 0.570
# 第1860步, 一个minibatch上的损失为 1.4378, 训练准确率为 0.539
# 第1870步, 一个minibatch上的损失为 1.4135, 训练准确率为 0.555
# 第1880步, 一个minibatch上的损失为 1.2750, 训练准确率为 0.617
# 第1890步, 一个minibatch上的损失为 1.1753, 训练准确率为 0.633
# 第1900步, 一个minibatch上的损失为 1.2817, 训练准确率为 0.617
# 第1910步, 一个minibatch上的损失为 1.3972, 训练准确率为 0.547
# 第1920步, 一个minibatch上的损失为 1.2829, 训练准确率为 0.594
# 第1930步, 一个minibatch上的损失为 1.3580, 训练准确率为 0.609
# 第1940步, 一个minibatch上的损失为 1.2240, 训练准确率为 0.633
# 第1950步, 一个minibatch上的损失为 1.3303, 训练准确率为 0.594
# 第1960步, 一个minibatch上的损失为 1.2059, 训练准确率为 0.703
# 第1970步, 一个minibatch上的损失为 1.2798, 训练准确率为 0.594
# 第1980步, 一个minibatch上的损失为 1.2980, 训练准确率为 0.609
# 第1990步, 一个minibatch上的损失为 1.2664, 训练准确率为 0.609
# 第2000步, 一个minibatch上的损失为 1.2162, 训练准确率为 0.625
# 第2010步, 一个minibatch上的损失为 1.3837, 训练准确率为 0.594
# 第2020步, 一个minibatch上的损失为 1.2318, 训练准确率为 0.609
# 第2030步, 一个minibatch上的损失为 1.2616, 训练准确率为 0.586
# 第2040步, 一个minibatch上的损失为 1.2431, 训练准确率为 0.570
# 第2050步, 一个minibatch上的损失为 1.4298, 训练准确率为 0.508
# 第2060步, 一个minibatch上的损失为 1.2900, 训练准确率为 0.586
# 第2070步, 一个minibatch上的损失为 1.2921, 训练准确率为 0.609
# 第2080步, 一个minibatch上的损失为 1.3760, 训练准确率为 0.562
# 第2090步, 一个minibatch上的损失为 1.4900, 训练准确率为 0.523
# 第2100步, 一个minibatch上的损失为 1.3952, 训练准确率为 0.523
# 第2110步, 一个minibatch上的损失为 1.3514, 训练准确率为 0.516
# 第2120步, 一个minibatch上的损失为 1.2430, 训练准确率为 0.602
# 第2130步, 一个minibatch上的损失为 1.1049, 训练准确率为 0.688
# 第2140步, 一个minibatch上的损失为 1.2372, 训练准确率为 0.602
# 第2150步, 一个minibatch上的损失为 1.2483, 训练准确率为 0.625
# 第2160步, 一个minibatch上的损失为 1.2337, 训练准确率为 0.602
# 第2170步, 一个minibatch上的损失为 1.3875, 训练准确率为 0.586
# 第2180步, 一个minibatch上的损失为 1.4207, 训练准确率为 0.547
# 第2190步, 一个minibatch上的损失为 1.3844, 训练准确率为 0.555
# 第2200步, 一个minibatch上的损失为 1.2554, 训练准确率为 0.594
# 第2210步, 一个minibatch上的损失为 1.4055, 训练准确率为 0.539
# 第2220步, 一个minibatch上的损失为 1.2006, 训练准确率为 0.617
# 第2230步, 一个minibatch上的损失为 1.2531, 训练准确率为 0.625
# 第2240步, 一个minibatch上的损失为 1.3659, 训练准确率为 0.508
# 第2250步, 一个minibatch上的损失为 1.2222, 训练准确率为 0.648
# 第2260步, 一个minibatch上的损失为 1.2559, 训练准确率为 0.578
# 第2270步, 一个minibatch上的损失为 1.3951, 训练准确率为 0.586
# 第2280步, 一个minibatch上的损失为 1.2091, 训练准确率为 0.648
# 第2290步, 一个minibatch上的损失为 1.2737, 训练准确率为 0.586
# 第2300步, 一个minibatch上的损失为 1.1928, 训练准确率为 0.664
# 第2310步, 一个minibatch上的损失为 1.1900, 训练准确率为 0.641
# 第2320步, 一个minibatch上的损失为 1.3160, 训练准确率为 0.523
# 第2330步, 一个minibatch上的损失为 1.3108, 训练准确率为 0.586
# 第2340步, 一个minibatch上的损失为 1.1661, 训练准确率为 0.625
# 第2350步, 一个minibatch上的损失为 1.2279, 训练准确率为 0.602
# 第2360步, 一个minibatch上的损失为 1.2611, 训练准确率为 0.672
# 第2370步, 一个minibatch上的损失为 1.2279, 训练准确率为 0.602
# 第2380步, 一个minibatch上的损失为 1.2450, 训练准确率为 0.609
# 第2390步, 一个minibatch上的损失为 1.2628, 训练准确率为 0.609
# 第2400步, 一个minibatch上的损失为 1.2431, 训练准确率为 0.594
# 第2410步, 一个minibatch上的损失为 1.2374, 训练准确率为 0.609
# 第2420步, 一个minibatch上的损失为 1.0989, 训练准确率为 0.648
# 第2430步, 一个minibatch上的损失为 1.2778, 训练准确率为 0.586
# 第2440步, 一个minibatch上的损失为 1.2980, 训练准确率为 0.570
# 第2450步, 一个minibatch上的损失为 1.2890, 训练准确率为 0.555
# 第2460步, 一个minibatch上的损失为 1.2471, 训练准确率为 0.570
# 第2470步, 一个minibatch上的损失为 1.2454, 训练准确率为 0.578
# 第2480步, 一个minibatch上的损失为 1.3148, 训练准确率为 0.562
# 第2490步, 一个minibatch上的损失为 1.3044, 训练准确率为 0.547
# 第2500步, 一个minibatch上的损失为 1.1950, 训练准确率为 0.594
# 第2510步, 一个minibatch上的损失为 1.0704, 训练准确率为 0.695
# 第2520步, 一个minibatch上的损失为 1.3100, 训练准确率为 0.578
# 第2530步, 一个minibatch上的损失为 1.1042, 训练准确率为 0.680
# 第2540步, 一个minibatch上的损失为 1.0252, 训练准确率为 0.680
# 第2550步, 一个minibatch上的损失为 1.1629, 训练准确率为 0.586
# 第2560步, 一个minibatch上的损失为 1.0854, 训练准确率为 0.656
# 第2570步, 一个minibatch上的损失为 1.3116, 训练准确率为 0.633
# 第2580步, 一个minibatch上的损失为 1.1352, 训练准确率为 0.695
# 第2590步, 一个minibatch上的损失为 1.1989, 训练准确率为 0.602
# 第2600步, 一个minibatch上的损失为 1.0902, 训练准确率为 0.664
# 第2610步, 一个minibatch上的损失为 1.2084, 训练准确率为 0.578
# 第2620步, 一个minibatch上的损失为 1.2124, 训练准确率为 0.602
# 第2630步, 一个minibatch上的损失为 1.2757, 训练准确率为 0.609
# 第2640步, 一个minibatch上的损失为 1.1550, 训练准确率为 0.617
# 第2650步, 一个minibatch上的损失为 1.3221, 训练准确率为 0.594
# 第2660步, 一个minibatch上的损失为 1.2303, 训练准确率为 0.664
# 第2670步, 一个minibatch上的损失为 1.2707, 训练准确率为 0.602
# 第2680步, 一个minibatch上的损失为 1.1687, 训练准确率为 0.664
# 第2690步, 一个minibatch上的损失为 1.2625, 训练准确率为 0.586
# 第2700步, 一个minibatch上的损失为 1.2477, 训练准确率为 0.547
# 第2710步, 一个minibatch上的损失为 1.1859, 训练准确率为 0.633
# 第2720步, 一个minibatch上的损失为 1.1116, 训练准确率为 0.688
# 第2730步, 一个minibatch上的损失为 1.1066, 训练准确率为 0.664
# 第2740步, 一个minibatch上的损失为 1.2454, 训练准确率为 0.648
# 第2750步, 一个minibatch上的损失为 1.0894, 训练准确率为 0.656
# 第2760步, 一个minibatch上的损失为 1.1935, 训练准确率为 0.625
# 第2770步, 一个minibatch上的损失为 1.1219, 训练准确率为 0.609
# 第2780步, 一个minibatch上的损失为 1.0199, 训练准确率为 0.680
# 第2790步, 一个minibatch上的损失为 1.1090, 训练准确率为 0.641
# 第2800步, 一个minibatch上的损失为 1.2125, 训练准确率为 0.578
# 第2810步, 一个minibatch上的损失为 1.0538, 训练准确率为 0.672
# 第2820步, 一个minibatch上的损失为 1.2125, 训练准确率为 0.594
# 第2830步, 一个minibatch上的损失为 1.0899, 训练准确率为 0.680
# 第2840步, 一个minibatch上的损失为 1.1698, 训练准确率为 0.625
# 第2850步, 一个minibatch上的损失为 1.1757, 训练准确率为 0.617
# 第2860步, 一个minibatch上的损失为 1.2039, 训练准确率为 0.562
# 第2870步, 一个minibatch上的损失为 1.3437, 训练准确率为 0.539
# 第2880步, 一个minibatch上的损失为 1.2936, 训练准确率为 0.547
# 第2890步, 一个minibatch上的损失为 1.0828, 训练准确率为 0.664
# 第2900步, 一个minibatch上的损失为 1.1920, 训练准确率为 0.633
# 第2910步, 一个minibatch上的损失为 1.0468, 训练准确率为 0.672
# 第2920步, 一个minibatch上的损失为 1.0253, 训练准确率为 0.703
# 第2930步, 一个minibatch上的损失为 1.0108, 训练准确率为 0.695
# 第2940步, 一个minibatch上的损失为 0.9567, 训练准确率为 0.727
# 第2950步, 一个minibatch上的损失为 1.0769, 训练准确率为 0.703
# 第2960步, 一个minibatch上的损失为 1.1317, 训练准确率为 0.672
# 第2970步, 一个minibatch上的损失为 1.1397, 训练准确率为 0.664
# 第2980步, 一个minibatch上的损失为 1.1440, 训练准确率为 0.688
# 第2990步, 一个minibatch上的损失为 1.1345, 训练准确率为 0.633
# 第3000步, 一个minibatch上的损失为 1.1327, 训练准确率为 0.625
# 第3010步, 一个minibatch上的损失为 1.2412, 训练准确率为 0.641
# 第3020步, 一个minibatch上的损失为 1.0875, 训练准确率为 0.711
# 第3030步, 一个minibatch上的损失为 1.1720, 训练准确率为 0.578
# 第3040步, 一个minibatch上的损失为 1.0854, 训练准确率为 0.664
# 第3050步, 一个minibatch上的损失为 1.0704, 训练准确率为 0.680
# 第3060步, 一个minibatch上的损失为 1.1141, 训练准确率为 0.672
# 第3070步, 一个minibatch上的损失为 0.9356, 训练准确率为 0.727
# 第3080步, 一个minibatch上的损失为 1.0741, 训练准确率为 0.664
# 第3090步, 一个minibatch上的损失为 1.1874, 训练准确率为 0.609
# 第3100步, 一个minibatch上的损失为 1.1280, 训练准确率为 0.641
# 第3110步, 一个minibatch上的损失为 1.0897, 训练准确率为 0.617
# 第3120步, 一个minibatch上的损失为 1.2818, 训练准确率为 0.602
# 第3130步, 一个minibatch上的损失为 1.1704, 训练准确率为 0.633
# 第3140步, 一个minibatch上的损失为 1.1065, 训练准确率为 0.633
# 第3150步, 一个minibatch上的损失为 1.0407, 训练准确率为 0.664
# 第3160步, 一个minibatch上的损失为 1.0500, 训练准确率为 0.680
# 第3170步, 一个minibatch上的损失为 1.0611, 训练准确率为 0.719
# 第3180步, 一个minibatch上的损失为 1.1665, 训练准确率为 0.609
# 第3190步, 一个minibatch上的损失为 1.0721, 训练准确率为 0.672
# 第3200步, 一个minibatch上的损失为 1.2030, 训练准确率为 0.625
# 第3210步, 一个minibatch上的损失为 1.2379, 训练准确率为 0.578
# 第3220步, 一个minibatch上的损失为 0.8841, 训练准确率为 0.719
# 第3230步, 一个minibatch上的损失为 1.1312, 训练准确率为 0.664
# 第3240步, 一个minibatch上的损失为 0.9795, 训练准确率为 0.727
# 第3250步, 一个minibatch上的损失为 1.1175, 训练准确率为 0.609
# 第3260步, 一个minibatch上的损失为 1.2646, 训练准确率为 0.586
# 第3270步, 一个minibatch上的损失为 1.0172, 训练准确率为 0.672
# 第3280步, 一个minibatch上的损失为 1.0599, 训练准确率为 0.664
# 第3290步, 一个minibatch上的损失为 1.1788, 训练准确率为 0.617
# 第3300步, 一个minibatch上的损失为 1.0671, 训练准确率为 0.680
# 第3310步, 一个minibatch上的损失为 0.9695, 训练准确率为 0.719
# 第3320步, 一个minibatch上的损失为 1.0605, 训练准确率为 0.688
# 第3330步, 一个minibatch上的损失为 1.1168, 训练准确率为 0.648
# 第3340步, 一个minibatch上的损失为 1.0641, 训练准确率为 0.672
# 第3350步, 一个minibatch上的损失为 1.0310, 训练准确率为 0.727
# 第3360步, 一个minibatch上的损失为 1.0138, 训练准确率为 0.680
# 第3370步, 一个minibatch上的损失为 1.0023, 训练准确率为 0.703
# 第3380步, 一个minibatch上的损失为 1.0282, 训练准确率为 0.680
# 第3390步, 一个minibatch上的损失为 1.0091, 训练准确率为 0.633
# 第3400步, 一个minibatch上的损失为 1.2660, 训练准确率为 0.594
# 第3410步, 一个minibatch上的损失为 1.1019, 训练准确率为 0.656
# 第3420步, 一个minibatch上的损失为 0.9243, 训练准确率为 0.734
# 第3430步, 一个minibatch上的损失为 0.9242, 训练准确率为 0.719
# 第3440步, 一个minibatch上的损失为 1.0552, 训练准确率为 0.688
# 第3450步, 一个minibatch上的损失为 1.0874, 训练准确率为 0.633
# 第3460步, 一个minibatch上的损失为 1.0116, 训练准确率为 0.711
# 第3470步, 一个minibatch上的损失为 0.9985, 训练准确率为 0.664
# 第3480步, 一个minibatch上的损失为 1.0280, 训练准确率为 0.719
# 第3490步, 一个minibatch上的损失为 0.9275, 训练准确率为 0.719
# 第3500步, 一个minibatch上的损失为 1.0154, 训练准确率为 0.664
# 第3510步, 一个minibatch上的损失为 1.0462, 训练准确率为 0.703
# 第3520步, 一个minibatch上的损失为 0.9627, 训练准确率为 0.688
# 第3530步, 一个minibatch上的损失为 1.1218, 训练准确率为 0.609
# 第3540步, 一个minibatch上的损失为 0.9565, 训练准确率为 0.758
# 第3550步, 一个minibatch上的损失为 0.9808, 训练准确率为 0.719
# 第3560步, 一个minibatch上的损失为 1.0479, 训练准确率为 0.680
# 第3570步, 一个minibatch上的损失为 1.0014, 训练准确率为 0.648
# 第3580步, 一个minibatch上的损失为 1.0263, 训练准确率为 0.648
# 第3590步, 一个minibatch上的损失为 0.9608, 训练准确率为 0.766
# 第3600步, 一个minibatch上的损失为 0.9907, 训练准确率为 0.734
# 第3610步, 一个minibatch上的损失为 1.0545, 训练准确率为 0.711
# 第3620步, 一个minibatch上的损失为 0.9528, 训练准确率为 0.742
# 第3630步, 一个minibatch上的损失为 0.8894, 训练准确率为 0.742
# 第3640步, 一个minibatch上的损失为 0.8550, 训练准确率为 0.773
# 第3650步, 一个minibatch上的损失为 1.0548, 训练准确率为 0.680
# 第3660步, 一个minibatch上的损失为 0.8923, 训练准确率为 0.734
# 第3670步, 一个minibatch上的损失为 1.0205, 训练准确率为 0.695
# 第3680步, 一个minibatch上的损失为 0.9809, 训练准确率为 0.703
# 第3690步, 一个minibatch上的损失为 0.9454, 训练准确率为 0.703
# 第3700步, 一个minibatch上的损失为 0.9158, 训练准确率为 0.727
# 第3710步, 一个minibatch上的损失为 0.9742, 训练准确率为 0.703
# 第3720步, 一个minibatch上的损失为 0.8583, 训练准确率为 0.797
# 第3730步, 一个minibatch上的损失为 0.9263, 训练准确率为 0.711
# 第3740步, 一个minibatch上的损失为 0.9304, 训练准确率为 0.766
# 第3750步, 一个minibatch上的损失为 1.0957, 训练准确率为 0.609
# 第3760步, 一个minibatch上的损失为 1.0726, 训练准确率为 0.695
# 第3770步, 一个minibatch上的损失为 1.0752, 训练准确率为 0.664
# 第3780步, 一个minibatch上的损失为 1.1146, 训练准确率为 0.648
# 第3790步, 一个minibatch上的损失为 1.1250, 训练准确率为 0.664
# 第3800步, 一个minibatch上的损失为 0.9472, 训练准确率为 0.656
# 第3810步, 一个minibatch上的损失为 1.0464, 训练准确率为 0.672
# 第3820步, 一个minibatch上的损失为 0.9418, 训练准确率为 0.703
# 第3830步, 一个minibatch上的损失为 0.9997, 训练准确率为 0.680
# 第3840步, 一个minibatch上的损失为 1.0223, 训练准确率为 0.656
# 第3850步, 一个minibatch上的损失为 1.0615, 训练准确率为 0.672
# 第3860步, 一个minibatch上的损失为 0.8032, 训练准确率为 0.758
# 第3870步, 一个minibatch上的损失为 0.9372, 训练准确率为 0.750
# 第3880步, 一个minibatch上的损失为 0.9886, 训练准确率为 0.727
# 第3890步, 一个minibatch上的损失为 0.9765, 训练准确率为 0.719
# 第3900步, 一个minibatch上的损失为 1.0043, 训练准确率为 0.688
# 第3910步, 一个minibatch上的损失为 0.8028, 训练准确率为 0.727
# 第3920步, 一个minibatch上的损失为 0.8740, 训练准确率为 0.703
# 第3930步, 一个minibatch上的损失为 0.9897, 训练准确率为 0.703
# 第3940步, 一个minibatch上的损失为 0.9673, 训练准确率为 0.703
# 第3950步, 一个minibatch上的损失为 0.8731, 训练准确率为 0.797
# 第3960步, 一个minibatch上的损失为 1.0799, 训练准确率为 0.688
# 第3970步, 一个minibatch上的损失为 1.0340, 训练准确率为 0.648
# 第3980步, 一个minibatch上的损失为 0.8178, 训练准确率为 0.750
# 第3990步, 一个minibatch上的损失为 1.2486, 训练准确率为 0.625
# 第4000步, 一个minibatch上的损失为 0.9538, 训练准确率为 0.734
# 第4010步, 一个minibatch上的损失为 0.9350, 训练准确率为 0.727
# 第4020步, 一个minibatch上的损失为 0.8624, 训练准确率为 0.672
# 第4030步, 一个minibatch上的损失为 0.8203, 训练准确率为 0.719
# 第4040步, 一个minibatch上的损失为 0.9868, 训练准确率为 0.648
# 第4050步, 一个minibatch上的损失为 0.7794, 训练准确率为 0.797
# 第4060步, 一个minibatch上的损失为 0.9644, 训练准确率为 0.750
# 第4070步, 一个minibatch上的损失为 1.0179, 训练准确率为 0.719
# 第4080步, 一个minibatch上的损失为 1.0421, 训练准确率为 0.719
# 第4090步, 一个minibatch上的损失为 0.9741, 训练准确率为 0.664
# 第4100步, 一个minibatch上的损失为 0.8736, 训练准确率为 0.727
# 第4110步, 一个minibatch上的损失为 0.8851, 训练准确率为 0.727
# 第4120步, 一个minibatch上的损失为 0.9940, 训练准确率为 0.688
# 第4130步, 一个minibatch上的损失为 0.8990, 训练准确率为 0.711
# 第4140步, 一个minibatch上的损失为 1.0480, 训练准确率为 0.680
# 第4150步, 一个minibatch上的损失为 1.0686, 训练准确率为 0.648
# 第4160步, 一个minibatch上的损失为 0.8672, 训练准确率为 0.711
# 第4170步, 一个minibatch上的损失为 0.9048, 训练准确率为 0.773
# 第4180步, 一个minibatch上的损失为 0.8135, 训练准确率为 0.781
# 第4190步, 一个minibatch上的损失为 0.9630, 训练准确率为 0.680
# 第4200步, 一个minibatch上的损失为 0.9445, 训练准确率为 0.711
# 第4210步, 一个minibatch上的损失为 0.8275, 训练准确率为 0.789
# 第4220步, 一个minibatch上的损失为 0.9500, 训练准确率为 0.656
# 第4230步, 一个minibatch上的损失为 0.9323, 训练准确率为 0.719
# 第4240步, 一个minibatch上的损失为 1.0886, 训练准确率为 0.664
# 第4250步, 一个minibatch上的损失为 0.8577, 训练准确率为 0.719
# 第4260步, 一个minibatch上的损失为 0.9953, 训练准确率为 0.641
# 第4270步, 一个minibatch上的损失为 1.0512, 训练准确率为 0.633
# 第4280步, 一个minibatch上的损失为 0.9400, 训练准确率为 0.688
# 第4290步, 一个minibatch上的损失为 0.9397, 训练准确率为 0.695
# 第4300步, 一个minibatch上的损失为 0.9909, 训练准确率为 0.688
# 第4310步, 一个minibatch上的损失为 1.0131, 训练准确率为 0.656
# 第4320步, 一个minibatch上的损失为 1.0138, 训练准确率为 0.703
# 第4330步, 一个minibatch上的损失为 1.2027, 训练准确率为 0.562
# 第4340步, 一个minibatch上的损失为 0.9465, 训练准确率为 0.703
# 第4350步, 一个minibatch上的损失为 0.8067, 训练准确率为 0.750
# 第4360步, 一个minibatch上的损失为 0.9296, 训练准确率为 0.719
# 第4370步, 一个minibatch上的损失为 0.9673, 训练准确率为 0.688
# 第4380步, 一个minibatch上的损失为 0.7975, 训练准确率为 0.805
# 第4390步, 一个minibatch上的损失为 0.9108, 训练准确率为 0.766
# 第4400步, 一个minibatch上的损失为 0.7422, 训练准确率为 0.727
# 第4410步, 一个minibatch上的损失为 0.8778, 训练准确率为 0.734
# 第4420步, 一个minibatch上的损失为 0.9980, 训练准确率为 0.672
# 第4430步, 一个minibatch上的损失为 0.7897, 训练准确率为 0.773
# 第4440步, 一个minibatch上的损失为 1.0065, 训练准确率为 0.680
# 第4450步, 一个minibatch上的损失为 1.0708, 训练准确率为 0.672
# 第4460步, 一个minibatch上的损失为 1.0105, 训练准确率为 0.695
# 第4470步, 一个minibatch上的损失为 0.8203, 训练准确率为 0.742
# 第4480步, 一个minibatch上的损失为 0.8525, 训练准确率为 0.734
# 第4490步, 一个minibatch上的损失为 0.8762, 训练准确率为 0.734
# 第4500步, 一个minibatch上的损失为 0.9004, 训练准确率为 0.727
# 第4510步, 一个minibatch上的损失为 0.9586, 训练准确率为 0.648
# 第4520步, 一个minibatch上的损失为 0.8490, 训练准确率为 0.742
# 第4530步, 一个minibatch上的损失为 0.9817, 训练准确率为 0.688
# 第4540步, 一个minibatch上的损失为 0.9022, 训练准确率为 0.734
# 第4550步, 一个minibatch上的损失为 0.8363, 训练准确率为 0.734
# 第4560步, 一个minibatch上的损失为 0.8810, 训练准确率为 0.703
# 第4570步, 一个minibatch上的损失为 0.9016, 训练准确率为 0.758
# 第4580步, 一个minibatch上的损失为 1.0196, 训练准确率为 0.648
# 第4590步, 一个minibatch上的损失为 0.8049, 训练准确率为 0.734
# 第4600步, 一个minibatch上的损失为 0.8225, 训练准确率为 0.773
# 第4610步, 一个minibatch上的损失为 0.9159, 训练准确率为 0.727
# 第4620步, 一个minibatch上的损失为 0.7499, 训练准确率为 0.766
# 第4630步, 一个minibatch上的损失为 0.9253, 训练准确率为 0.734
# 第4640步, 一个minibatch上的损失为 0.8368, 训练准确率为 0.742
# 第4650步, 一个minibatch上的损失为 0.7732, 训练准确率为 0.742
# 第4660步, 一个minibatch上的损失为 0.8952, 训练准确率为 0.750
# 第4670步, 一个minibatch上的损失为 0.8747, 训练准确率为 0.773
# 第4680步, 一个minibatch上的损失为 0.9318, 训练准确率为 0.695
# 第4690步, 一个minibatch上的损失为 0.8793, 训练准确率为 0.734
# 第4700步, 一个minibatch上的损失为 0.8914, 训练准确率为 0.711
# 第4710步, 一个minibatch上的损失为 0.8240, 训练准确率为 0.766
# 第4720步, 一个minibatch上的损失为 0.8163, 训练准确率为 0.734
# 第4730步, 一个minibatch上的损失为 0.7596, 训练准确率为 0.766
# 第4740步, 一个minibatch上的损失为 0.8192, 训练准确率为 0.742
# 第4750步, 一个minibatch上的损失为 0.7941, 训练准确率为 0.766
# 第4760步, 一个minibatch上的损失为 0.9372, 训练准确率为 0.656
# 第4770步, 一个minibatch上的损失为 0.7965, 训练准确率为 0.797
# 第4780步, 一个minibatch上的损失为 0.8193, 训练准确率为 0.734
# 第4790步, 一个minibatch上的损失为 0.8983, 训练准确率为 0.695
# 第4800步, 一个minibatch上的损失为 0.8367, 训练准确率为 0.711
# 第4810步, 一个minibatch上的损失为 0.8758, 训练准确率为 0.727
# 第4820步, 一个minibatch上的损失为 0.7731, 训练准确率为 0.766
# 第4830步, 一个minibatch上的损失为 0.8537, 训练准确率为 0.758
# 第4840步, 一个minibatch上的损失为 0.9832, 训练准确率为 0.680
# 第4850步, 一个minibatch上的损失为 0.9542, 训练准确率为 0.672
# 第4860步, 一个minibatch上的损失为 0.8215, 训练准确率为 0.719
# 第4870步, 一个minibatch上的损失为 0.9598, 训练准确率为 0.680
# 第4880步, 一个minibatch上的损失为 0.8523, 训练准确率为 0.711
# 第4890步, 一个minibatch上的损失为 0.7414, 训练准确率为 0.789
# 第4900步, 一个minibatch上的损失为 0.7860, 训练准确率为 0.727
# 第4910步, 一个minibatch上的损失为 0.8876, 训练准确率为 0.711
# 第4920步, 一个minibatch上的损失为 0.8425, 训练准确率为 0.758
# 第4930步, 一个minibatch上的损失为 0.8381, 训练准确率为 0.680
# 第4940步, 一个minibatch上的损失为 0.7379, 训练准确率为 0.758
# 第4950步, 一个minibatch上的损失为 0.8893, 训练准确率为 0.742
# 第4960步, 一个minibatch上的损失为 0.7930, 训练准确率为 0.750
# 第4970步, 一个minibatch上的损失为 0.8669, 训练准确率为 0.734
# 第4980步, 一个minibatch上的损失为 0.8698, 训练准确率为 0.773
# 第4990步, 一个minibatch上的损失为 0.9794, 训练准确率为 0.680
# 第5000步, 一个minibatch上的损失为 0.9042, 训练准确率为 0.672
# 第5010步, 一个minibatch上的损失为 0.8377, 训练准确率为 0.734
# 第5020步, 一个minibatch上的损失为 1.0194, 训练准确率为 0.703
# 第5030步, 一个minibatch上的损失为 0.9032, 训练准确率为 0.734
# 第5040步, 一个minibatch上的损失为 0.8569, 训练准确率为 0.734
# 第5050步, 一个minibatch上的损失为 0.8180, 训练准确率为 0.758
# 第5060步, 一个minibatch上的损失为 0.7734, 训练准确率为 0.773
# 第5070步, 一个minibatch上的损失为 0.9572, 训练准确率为 0.648
# 第5080步, 一个minibatch上的损失为 0.8925, 训练准确率为 0.750
# 第5090步, 一个minibatch上的损失为 0.8368, 训练准确率为 0.727
# 第5100步, 一个minibatch上的损失为 0.6448, 训练准确率为 0.797
# 第5110步, 一个minibatch上的损失为 0.9269, 训练准确率为 0.766
# 第5120步, 一个minibatch上的损失为 0.8985, 训练准确率为 0.672
# 第5130步, 一个minibatch上的损失为 0.8953, 训练准确率为 0.703
# 第5140步, 一个minibatch上的损失为 0.8749, 训练准确率为 0.656
# 第5150步, 一个minibatch上的损失为 0.7050, 训练准确率为 0.781
# 第5160步, 一个minibatch上的损失为 0.7363, 训练准确率为 0.742
# 第5170步, 一个minibatch上的损失为 0.7464, 训练准确率为 0.758
# 第5180步, 一个minibatch上的损失为 0.8300, 训练准确率为 0.703
# 第5190步, 一个minibatch上的损失为 0.9104, 训练准确率为 0.648
# 第5200步, 一个minibatch上的损失为 0.8931, 训练准确率为 0.727
# 第5210步, 一个minibatch上的损失为 0.8282, 训练准确率为 0.758
# 第5220步, 一个minibatch上的损失为 0.7019, 训练准确率为 0.758
# 第5230步, 一个minibatch上的损失为 0.7185, 训练准确率为 0.781
# 第5240步, 一个minibatch上的损失为 0.8514, 训练准确率为 0.695
# 第5250步, 一个minibatch上的损失为 0.7561, 训练准确率为 0.812
# 第5260步, 一个minibatch上的损失为 0.7449, 训练准确率为 0.789
# 第5270步, 一个minibatch上的损失为 0.8343, 训练准确率为 0.773
# 第5280步, 一个minibatch上的损失为 0.7132, 训练准确率为 0.812
# 第5290步, 一个minibatch上的损失为 0.7890, 训练准确率为 0.727
# 第5300步, 一个minibatch上的损失为 0.7736, 训练准确率为 0.742
# 第5310步, 一个minibatch上的损失为 0.7203, 训练准确率为 0.781
# 第5320步, 一个minibatch上的损失为 0.9649, 训练准确率为 0.711
# 第5330步, 一个minibatch上的损失为 0.9131, 训练准确率为 0.742
# 第5340步, 一个minibatch上的损失为 0.7714, 训练准确率为 0.750
# 第5350步, 一个minibatch上的损失为 0.6801, 训练准确率为 0.812
# 第5360步, 一个minibatch上的损失为 0.7492, 训练准确率为 0.773
# 第5370步, 一个minibatch上的损失为 0.6505, 训练准确率为 0.789
# 第5380步, 一个minibatch上的损失为 0.6624, 训练准确率为 0.812
# 第5390步, 一个minibatch上的损失为 0.8774, 训练准确率为 0.727
# 第5400步, 一个minibatch上的损失为 0.6952, 训练准确率为 0.789
# 第5410步, 一个minibatch上的损失为 0.6639, 训练准确率为 0.820
# 第5420步, 一个minibatch上的损失为 0.8710, 训练准确率为 0.758
# 第5430步, 一个minibatch上的损失为 0.5752, 训练准确率为 0.820
# 第5440步, 一个minibatch上的损失为 0.7341, 训练准确率为 0.719
# 第5450步, 一个minibatch上的损失为 0.7805, 训练准确率为 0.766
# 第5460步, 一个minibatch上的损失为 0.7136, 训练准确率为 0.797
# 第5470步, 一个minibatch上的损失为 0.8435, 训练准确率为 0.719
# 第5480步, 一个minibatch上的损失为 0.8736, 训练准确率为 0.734
# 第5490步, 一个minibatch上的损失为 0.7513, 训练准确率为 0.734
# 第5500步, 一个minibatch上的损失为 0.7646, 训练准确率为 0.766
# 第5510步, 一个minibatch上的损失为 0.7619, 训练准确率为 0.789
# 第5520步, 一个minibatch上的损失为 1.0168, 训练准确率为 0.672
# 第5530步, 一个minibatch上的损失为 0.6837, 训练准确率为 0.789
# 第5540步, 一个minibatch上的损失为 0.7040, 训练准确率为 0.742
# 第5550步, 一个minibatch上的损失为 0.7842, 训练准确率为 0.758
# 第5560步, 一个minibatch上的损失为 0.8769, 训练准确率为 0.727
# 第5570步, 一个minibatch上的损失为 0.7072, 训练准确率为 0.750
# 第5580步, 一个minibatch上的损失为 0.8746, 训练准确率为 0.766
# 第5590步, 一个minibatch上的损失为 0.6786, 训练准确率为 0.797
# 第5600步, 一个minibatch上的损失为 0.7343, 训练准确率为 0.781
# 第5610步, 一个minibatch上的损失为 0.8145, 训练准确率为 0.758
# 第5620步, 一个minibatch上的损失为 0.7446, 训练准确率为 0.734
# 第5630步, 一个minibatch上的损失为 0.7655, 训练准确率为 0.758
# 第5640步, 一个minibatch上的损失为 0.7619, 训练准确率为 0.773
# 第5650步, 一个minibatch上的损失为 0.6670, 训练准确率为 0.836
# 第5660步, 一个minibatch上的损失为 0.7700, 训练准确率为 0.734
# 第5670步, 一个minibatch上的损失为 0.6934, 训练准确率为 0.781
# 第5680步, 一个minibatch上的损失为 0.7454, 训练准确率为 0.758
# 第5690步, 一个minibatch上的损失为 0.7230, 训练准确率为 0.797
# 第5700步, 一个minibatch上的损失为 0.7456, 训练准确率为 0.797
# 第5710步, 一个minibatch上的损失为 0.8129, 训练准确率为 0.734
# 第5720步, 一个minibatch上的损失为 0.9004, 训练准确率为 0.656
# 第5730步, 一个minibatch上的损失为 0.7238, 训练准确率为 0.758
# 第5740步, 一个minibatch上的损失为 0.7568, 训练准确率为 0.727
# 第5750步, 一个minibatch上的损失为 0.8608, 训练准确率为 0.727
# 第5760步, 一个minibatch上的损失为 0.8042, 训练准确率为 0.727
# 第5770步, 一个minibatch上的损失为 0.6263, 训练准确率为 0.781
# 第5780步, 一个minibatch上的损失为 0.7607, 训练准确率为 0.734
# 第5790步, 一个minibatch上的损失为 0.7388, 训练准确率为 0.773
# 第5800步, 一个minibatch上的损失为 0.8447, 训练准确率为 0.773
# 第5810步, 一个minibatch上的损失为 0.7547, 训练准确率为 0.758
# 第5820步, 一个minibatch上的损失为 0.6840, 训练准确率为 0.820
# 第5830步, 一个minibatch上的损失为 0.6925, 训练准确率为 0.766
# 第5840步, 一个minibatch上的损失为 0.6365, 训练准确率为 0.805
# 第5850步, 一个minibatch上的损失为 0.6848, 训练准确率为 0.766
# 第5860步, 一个minibatch上的损失为 0.7487, 训练准确率为 0.750
# 第5870步, 一个minibatch上的损失为 0.7325, 训练准确率为 0.773
# 第5880步, 一个minibatch上的损失为 0.7755, 训练准确率为 0.727
# 第5890步, 一个minibatch上的损失为 0.8595, 训练准确率为 0.734
# 第5900步, 一个minibatch上的损失为 0.8863, 训练准确率为 0.727
# 第5910步, 一个minibatch上的损失为 0.7153, 训练准确率为 0.797
# 第5920步, 一个minibatch上的损失为 0.7539, 训练准确率为 0.742
# 第5930步, 一个minibatch上的损失为 0.7119, 训练准确率为 0.750
# 第5940步, 一个minibatch上的损失为 0.6957, 训练准确率为 0.766
# 第5950步, 一个minibatch上的损失为 0.7013, 训练准确率为 0.789
# 第5960步, 一个minibatch上的损失为 0.6484, 训练准确率为 0.805
# 第5970步, 一个minibatch上的损失为 0.5936, 训练准确率为 0.812
# 第5980步, 一个minibatch上的损失为 0.7258, 训练准确率为 0.758
# 第5990步, 一个minibatch上的损失为 0.9511, 训练准确率为 0.703
# 第6000步, 一个minibatch上的损失为 0.6650, 训练准确率为 0.820
# 第6010步, 一个minibatch上的损失为 0.7102, 训练准确率为 0.766
# 第6020步, 一个minibatch上的损失为 0.5953, 训练准确率为 0.844
# 第6030步, 一个minibatch上的损失为 0.6843, 训练准确率为 0.805
# 第6040步, 一个minibatch上的损失为 0.6935, 训练准确率为 0.742
# 第6050步, 一个minibatch上的损失为 0.7082, 训练准确率为 0.766
# 第6060步, 一个minibatch上的损失为 0.6969, 训练准确率为 0.766
# 第6070步, 一个minibatch上的损失为 0.6603, 训练准确率为 0.828
# 第6080步, 一个minibatch上的损失为 0.7038, 训练准确率为 0.812
# 第6090步, 一个minibatch上的损失为 0.6240, 训练准确率为 0.789
# 第6100步, 一个minibatch上的损失为 0.6538, 训练准确率为 0.828
# 第6110步, 一个minibatch上的损失为 0.7474, 训练准确率为 0.734
# 第6120步, 一个minibatch上的损失为 0.7933, 训练准确率为 0.711
# 第6130步, 一个minibatch上的损失为 0.6413, 训练准确率为 0.789
# 第6140步, 一个minibatch上的损失为 0.7095, 训练准确率为 0.773
# 第6150步, 一个minibatch上的损失为 0.6459, 训练准确率为 0.828
# 第6160步, 一个minibatch上的损失为 0.7769, 训练准确率为 0.734
# 第6170步, 一个minibatch上的损失为 0.7513, 训练准确率为 0.727
# 第6180步, 一个minibatch上的损失为 0.7687, 训练准确率为 0.734
# 第6190步, 一个minibatch上的损失为 0.8338, 训练准确率为 0.719
# 第6200步, 一个minibatch上的损失为 0.7057, 训练准确率为 0.797
# 第6210步, 一个minibatch上的损失为 0.6116, 训练准确率为 0.789
# 第6220步, 一个minibatch上的损失为 0.7070, 训练准确率为 0.797
# 第6230步, 一个minibatch上的损失为 0.6677, 训练准确率为 0.797
# 第6240步, 一个minibatch上的损失为 0.6774, 训练准确率为 0.805
# 第6250步, 一个minibatch上的损失为 0.8408, 训练准确率为 0.758
# 第6260步, 一个minibatch上的损失为 0.6227, 训练准确率为 0.797
# 第6270步, 一个minibatch上的损失为 0.5599, 训练准确率为 0.875
# 第6280步, 一个minibatch上的损失为 0.6437, 训练准确率为 0.781
# 第6290步, 一个minibatch上的损失为 0.8856, 训练准确率为 0.750
# 第6300步, 一个minibatch上的损失为 0.7377, 训练准确率为 0.789
# 第6310步, 一个minibatch上的损失为 0.6798, 训练准确率为 0.742
# 第6320步, 一个minibatch上的损失为 0.7134, 训练准确率为 0.727
# 第6330步, 一个minibatch上的损失为 0.7171, 训练准确率为 0.773
# 第6340步, 一个minibatch上的损失为 0.6505, 训练准确率为 0.773
# 第6350步, 一个minibatch上的损失为 0.7115, 训练准确率为 0.758
# 第6360步, 一个minibatch上的损失为 0.5803, 训练准确率为 0.828
# 第6370步, 一个minibatch上的损失为 0.7340, 训练准确率为 0.750
# 第6380步, 一个minibatch上的损失为 0.7316, 训练准确率为 0.781
# 第6390步, 一个minibatch上的损失为 0.6246, 训练准确率为 0.812
# 第6400步, 一个minibatch上的损失为 0.6996, 训练准确率为 0.734
# 第6410步, 一个minibatch上的损失为 0.6128, 训练准确率为 0.758
# 第6420步, 一个minibatch上的损失为 0.8311, 训练准确率为 0.734
# 第6430步, 一个minibatch上的损失为 0.6077, 训练准确率为 0.812
# 第6440步, 一个minibatch上的损失为 0.7565, 训练准确率为 0.719
# 第6450步, 一个minibatch上的损失为 0.7570, 训练准确率为 0.742
# 第6460步, 一个minibatch上的损失为 0.5716, 训练准确率为 0.836
# 第6470步, 一个minibatch上的损失为 0.5794, 训练准确率为 0.828
# 第6480步, 一个minibatch上的损失为 0.6671, 训练准确率为 0.820
# 第6490步, 一个minibatch上的损失为 0.7096, 训练准确率为 0.789
# 第6500步, 一个minibatch上的损失为 0.7121, 训练准确率为 0.766
# 第6510步, 一个minibatch上的损失为 0.7286, 训练准确率为 0.734
# 第6520步, 一个minibatch上的损失为 0.7119, 训练准确率为 0.766
# 第6530步, 一个minibatch上的损失为 0.6324, 训练准确率为 0.867
# 第6540步, 一个minibatch上的损失为 0.7624, 训练准确率为 0.734
# 第6550步, 一个minibatch上的损失为 0.6482, 训练准确率为 0.805
# 第6560步, 一个minibatch上的损失为 0.7191, 训练准确率为 0.766
# 第6570步, 一个minibatch上的损失为 0.8110, 训练准确率为 0.758
# 第6580步, 一个minibatch上的损失为 0.6085, 训练准确率为 0.828
# 第6590步, 一个minibatch上的损失为 0.5959, 训练准确率为 0.812
# 第6600步, 一个minibatch上的损失为 0.5560, 训练准确率为 0.820
# 第6610步, 一个minibatch上的损失为 0.6965, 训练准确率为 0.820
# 第6620步, 一个minibatch上的损失为 0.5730, 训练准确率为 0.836
# 第6630步, 一个minibatch上的损失为 0.6697, 训练准确率为 0.789
# 第6640步, 一个minibatch上的损失为 0.6754, 训练准确率为 0.773
# 第6650步, 一个minibatch上的损失为 0.7406, 训练准确率为 0.812
# 第6660步, 一个minibatch上的损失为 0.7177, 训练准确率为 0.766
# 第6670步, 一个minibatch上的损失为 0.5904, 训练准确率为 0.812
# 第6680步, 一个minibatch上的损失为 0.6520, 训练准确率为 0.766
# 第6690步, 一个minibatch上的损失为 0.5440, 训练准确率为 0.852
# 第6700步, 一个minibatch上的损失为 0.6176, 训练准确率为 0.828
# 第6710步, 一个minibatch上的损失为 0.6456, 训练准确率为 0.773
# 第6720步, 一个minibatch上的损失为 0.6788, 训练准确率为 0.797
# 第6730步, 一个minibatch上的损失为 0.6616, 训练准确率为 0.797
# 第6740步, 一个minibatch上的损失为 0.5691, 训练准确率为 0.828
# 第6750步, 一个minibatch上的损失为 0.7203, 训练准确率为 0.805
# 第6760步, 一个minibatch上的损失为 0.5741, 训练准确率为 0.859
# 第6770步, 一个minibatch上的损失为 0.6059, 训练准确率为 0.797
# 第6780步, 一个minibatch上的损失为 0.5379, 训练准确率为 0.852
# 第6790步, 一个minibatch上的损失为 0.7817, 训练准确率为 0.773
# 第6800步, 一个minibatch上的损失为 0.6281, 训练准确率为 0.812
# 第6810步, 一个minibatch上的损失为 0.7937, 训练准确率为 0.797
# 第6820步, 一个minibatch上的损失为 0.7441, 训练准确率为 0.766
# 第6830步, 一个minibatch上的损失为 0.6551, 训练准确率为 0.766
# 第6840步, 一个minibatch上的损失为 0.5182, 训练准确率为 0.836
# 第6850步, 一个minibatch上的损失为 0.6473, 训练准确率为 0.789
# 第6860步, 一个minibatch上的损失为 0.7121, 训练准确率为 0.742
# 第6870步, 一个minibatch上的损失为 0.6882, 训练准确率为 0.805
# 第6880步, 一个minibatch上的损失为 0.6449, 训练准确率为 0.812
# 第6890步, 一个minibatch上的损失为 0.6537, 训练准确率为 0.789
# 第6900步, 一个minibatch上的损失为 0.6070, 训练准确率为 0.836
# 第6910步, 一个minibatch上的损失为 0.6576, 训练准确率为 0.797
# 第6920步, 一个minibatch上的损失为 0.6218, 训练准确率为 0.797
# 第6930步, 一个minibatch上的损失为 0.6592, 训练准确率为 0.773
# 第6940步, 一个minibatch上的损失为 0.5715, 训练准确率为 0.805
# 第6950步, 一个minibatch上的损失为 0.6501, 训练准确率为 0.797
# 第6960步, 一个minibatch上的损失为 0.5543, 训练准确率为 0.797
# 第6970步, 一个minibatch上的损失为 0.6262, 训练准确率为 0.797
# 第6980步, 一个minibatch上的损失为 0.7011, 训练准确率为 0.805
# 第6990步, 一个minibatch上的损失为 0.8334, 训练准确率为 0.758
# 第7000步, 一个minibatch上的损失为 0.6685, 训练准确率为 0.797
# 第7010步, 一个minibatch上的损失为 0.5858, 训练准确率为 0.828
# 第7020步, 一个minibatch上的损失为 0.7661, 训练准确率为 0.758
# 第7030步, 一个minibatch上的损失为 0.6527, 训练准确率为 0.789
# 第7040步, 一个minibatch上的损失为 0.6202, 训练准确率为 0.773
# 第7050步, 一个minibatch上的损失为 0.5906, 训练准确率为 0.852
# 第7060步, 一个minibatch上的损失为 0.8504, 训练准确率为 0.781
# 第7070步, 一个minibatch上的损失为 0.5777, 训练准确率为 0.836
# 第7080步, 一个minibatch上的损失为 0.5042, 训练准确率为 0.852
# 第7090步, 一个minibatch上的损失为 0.5631, 训练准确率为 0.836
# 第7100步, 一个minibatch上的损失为 0.5842, 训练准确率为 0.828
# 第7110步, 一个minibatch上的损失为 0.6571, 训练准确率为 0.781
# 第7120步, 一个minibatch上的损失为 0.8302, 训练准确率为 0.734
# 第7130步, 一个minibatch上的损失为 0.6921, 训练准确率为 0.820
# 第7140步, 一个minibatch上的损失为 0.7838, 训练准确率为 0.766
# 第7150步, 一个minibatch上的损失为 0.7921, 训练准确率为 0.750
# 第7160步, 一个minibatch上的损失为 0.6515, 训练准确率为 0.781
# 第7170步, 一个minibatch上的损失为 0.6329, 训练准确率为 0.797
# 第7180步, 一个minibatch上的损失为 0.5975, 训练准确率为 0.828
# 第7190步, 一个minibatch上的损失为 0.5273, 训练准确率为 0.828
# 第7200步, 一个minibatch上的损失为 0.5885, 训练准确率为 0.828
# 第7210步, 一个minibatch上的损失为 0.6890, 训练准确率为 0.797
# 第7220步, 一个minibatch上的损失为 0.6499, 训练准确率为 0.773
# 第7230步, 一个minibatch上的损失为 0.4979, 训练准确率为 0.852
# 第7240步, 一个minibatch上的损失为 0.7060, 训练准确率为 0.758
# 第7250步, 一个minibatch上的损失为 0.5485, 训练准确率为 0.836
# 第7260步, 一个minibatch上的损失为 0.5841, 训练准确率为 0.828
# 第7270步, 一个minibatch上的损失为 0.7559, 训练准确率为 0.773
# 第7280步, 一个minibatch上的损失为 0.5636, 训练准确率为 0.828
# 第7290步, 一个minibatch上的损失为 0.5184, 训练准确率为 0.844
# 第7300步, 一个minibatch上的损失为 0.4388, 训练准确率为 0.883
# 第7310步, 一个minibatch上的损失为 0.5579, 训练准确率为 0.828
# 第7320步, 一个minibatch上的损失为 0.5356, 训练准确率为 0.812
# 第7330步, 一个minibatch上的损失为 0.5423, 训练准确率为 0.828
# 第7340步, 一个minibatch上的损失为 0.6405, 训练准确率为 0.812
# 第7350步, 一个minibatch上的损失为 0.5971, 训练准确率为 0.797
# 第7360步, 一个minibatch上的损失为 0.6840, 训练准确率为 0.766
# 第7370步, 一个minibatch上的损失为 0.7141, 训练准确率为 0.758
# 第7380步, 一个minibatch上的损失为 0.5998, 训练准确率为 0.812
# 第7390步, 一个minibatch上的损失为 0.5659, 训练准确率为 0.844
# 第7400步, 一个minibatch上的损失为 0.6662, 训练准确率为 0.789
# 第7410步, 一个minibatch上的损失为 0.5729, 训练准确率为 0.797
# 第7420步, 一个minibatch上的损失为 0.6331, 训练准确率为 0.820
# 第7430步, 一个minibatch上的损失为 0.6174, 训练准确率为 0.789
# 第7440步, 一个minibatch上的损失为 0.6883, 训练准确率为 0.805
# 第7450步, 一个minibatch上的损失为 0.6132, 训练准确率为 0.812
# 第7460步, 一个minibatch上的损失为 0.6128, 训练准确率为 0.805
# 第7470步, 一个minibatch上的损失为 0.5691, 训练准确率为 0.789
# 第7480步, 一个minibatch上的损失为 0.5717, 训练准确率为 0.828
# 第7490步, 一个minibatch上的损失为 0.6624, 训练准确率为 0.797
# 第7500步, 一个minibatch上的损失为 0.5932, 训练准确率为 0.836
# 第7510步, 一个minibatch上的损失为 0.6030, 训练准确率为 0.773
# 第7520步, 一个minibatch上的损失为 0.6353, 训练准确率为 0.812
# 第7530步, 一个minibatch上的损失为 0.4887, 训练准确率为 0.867
# 第7540步, 一个minibatch上的损失为 0.6487, 训练准确率为 0.758
# 第7550步, 一个minibatch上的损失为 0.4085, 训练准确率为 0.891
# 第7560步, 一个minibatch上的损失为 0.5152, 训练准确率为 0.820
# 第7570步, 一个minibatch上的损失为 0.5843, 训练准确率为 0.828
# 第7580步, 一个minibatch上的损失为 0.6633, 训练准确率为 0.797
# 第7590步, 一个minibatch上的损失为 0.6354, 训练准确率为 0.797
# 第7600步, 一个minibatch上的损失为 0.4340, 训练准确率为 0.883
# 第7610步, 一个minibatch上的损失为 0.5506, 训练准确率为 0.828
# 第7620步, 一个minibatch上的损失为 0.7730, 训练准确率为 0.781
# 第7630步, 一个minibatch上的损失为 0.5048, 训练准确率为 0.844
# 第7640步, 一个minibatch上的损失为 0.6894, 训练准确率为 0.789
# 第7650步, 一个minibatch上的损失为 0.5960, 训练准确率为 0.836
# 第7660步, 一个minibatch上的损失为 0.5630, 训练准确率为 0.805
# 第7670步, 一个minibatch上的损失为 0.4556, 训练准确率为 0.859
# 第7680步, 一个minibatch上的损失为 0.4974, 训练准确率为 0.836
# 第7690步, 一个minibatch上的损失为 0.5877, 训练准确率为 0.805
# 第7700步, 一个minibatch上的损失为 0.5913, 训练准确率为 0.781
# 第7710步, 一个minibatch上的损失为 0.6195, 训练准确率为 0.797
# 第7720步, 一个minibatch上的损失为 0.5465, 训练准确率为 0.812
# 第7730步, 一个minibatch上的损失为 0.5948, 训练准确率为 0.797
# 第7740步, 一个minibatch上的损失为 0.6281, 训练准确率为 0.805
# 第7750步, 一个minibatch上的损失为 0.6785, 训练准确率为 0.750
# 第7760步, 一个minibatch上的损失为 0.5651, 训练准确率为 0.852
# 第7770步, 一个minibatch上的损失为 0.5320, 训练准确率为 0.812
# 第7780步, 一个minibatch上的损失为 0.7637, 训练准确率为 0.742
# 第7790步, 一个minibatch上的损失为 0.5416, 训练准确率为 0.797
# 第7800步, 一个minibatch上的损失为 0.5351, 训练准确率为 0.844
# 第7810步, 一个minibatch上的损失为 0.5822, 训练准确率为 0.820
# 第7820步, 一个minibatch上的损失为 0.6027, 训练准确率为 0.836
# 第7830步, 一个minibatch上的损失为 0.6145, 训练准确率为 0.805
# 第7840步, 一个minibatch上的损失为 0.4996, 训练准确率为 0.867
# 第7850步, 一个minibatch上的损失为 0.6163, 训练准确率为 0.805
# 第7860步, 一个minibatch上的损失为 0.6784, 训练准确率为 0.773
# 第7870步, 一个minibatch上的损失为 0.6286, 训练准确率为 0.805
# 第7880步, 一个minibatch上的损失为 0.5621, 训练准确率为 0.789
# 第7890步, 一个minibatch上的损失为 0.6372, 训练准确率为 0.758
# 第7900步, 一个minibatch上的损失为 0.5651, 训练准确率为 0.805
# 第7910步, 一个minibatch上的损失为 0.4980, 训练准确率为 0.836
# 第7920步, 一个minibatch上的损失为 0.5909, 训练准确率为 0.820
# 第7930步, 一个minibatch上的损失为 0.6216, 训练准确率为 0.812
# 第7940步, 一个minibatch上的损失为 0.6275, 训练准确率为 0.781
# 第7950步, 一个minibatch上的损失为 0.4344, 训练准确率为 0.906
# 第7960步, 一个minibatch上的损失为 0.4893, 训练准确率为 0.852
# 第7970步, 一个minibatch上的损失为 0.5200, 训练准确率为 0.859
# 第7980步, 一个minibatch上的损失为 0.5567, 训练准确率为 0.844
# 第7990步, 一个minibatch上的损失为 0.4073, 训练准确率为 0.867
# 第8000步, 一个minibatch上的损失为 0.4858, 训练准确率为 0.828
# 第8010步, 一个minibatch上的损失为 0.5599, 训练准确率为 0.812
# 第8020步, 一个minibatch上的损失为 0.5659, 训练准确率为 0.812
# 第8030步, 一个minibatch上的损失为 0.6187, 训练准确率为 0.836
# 第8040步, 一个minibatch上的损失为 0.5866, 训练准确率为 0.797
# 第8050步, 一个minibatch上的损失为 0.5532, 训练准确率为 0.820
# 第8060步, 一个minibatch上的损失为 0.5493, 训练准确率为 0.820
# 第8070步, 一个minibatch上的损失为 0.4730, 训练准确率为 0.859
# 第8080步, 一个minibatch上的损失为 0.5717, 训练准确率为 0.805
# 第8090步, 一个minibatch上的损失为 0.6598, 训练准确率为 0.773
# 第8100步, 一个minibatch上的损失为 0.6912, 训练准确率为 0.758
# 第8110步, 一个minibatch上的损失为 0.4811, 训练准确率为 0.852
# 第8120步, 一个minibatch上的损失为 0.5211, 训练准确率为 0.828
# 第8130步, 一个minibatch上的损失为 0.5670, 训练准确率为 0.797
# 第8140步, 一个minibatch上的损失为 0.5595, 训练准确率为 0.805
# 第8150步, 一个minibatch上的损失为 0.6827, 训练准确率为 0.812
# 第8160步, 一个minibatch上的损失为 0.5195, 训练准确率为 0.797
# 第8170步, 一个minibatch上的损失为 0.6943, 训练准确率为 0.773
# 第8180步, 一个minibatch上的损失为 0.6283, 训练准确率为 0.781
# 第8190步, 一个minibatch上的损失为 0.3819, 训练准确率为 0.883
# 第8200步, 一个minibatch上的损失为 0.4961, 训练准确率为 0.875
# 第8210步, 一个minibatch上的损失为 0.6711, 训练准确率为 0.805
# 第8220步, 一个minibatch上的损失为 0.6252, 训练准确率为 0.797
# 第8230步, 一个minibatch上的损失为 0.4752, 训练准确率为 0.828
# 第8240步, 一个minibatch上的损失为 0.5376, 训练准确率为 0.836
# 第8250步, 一个minibatch上的损失为 0.5792, 训练准确率为 0.805
# 第8260步, 一个minibatch上的损失为 0.5777, 训练准确率为 0.844
# 第8270步, 一个minibatch上的损失为 0.4608, 训练准确率为 0.836
# 第8280步, 一个minibatch上的损失为 0.5142, 训练准确率为 0.828
# 第8290步, 一个minibatch上的损失为 0.5404, 训练准确率为 0.812
# 第8300步, 一个minibatch上的损失为 0.6058, 训练准确率为 0.820
# 第8310步, 一个minibatch上的损失为 0.5111, 训练准确率为 0.844
# 第8320步, 一个minibatch上的损失为 0.5214, 训练准确率为 0.844
# 第8330步, 一个minibatch上的损失为 0.5010, 训练准确率为 0.852
# 第8340步, 一个minibatch上的损失为 0.5632, 训练准确率为 0.836
# 第8350步, 一个minibatch上的损失为 0.5713, 训练准确率为 0.875
# 第8360步, 一个minibatch上的损失为 0.6555, 训练准确率为 0.797
# 第8370步, 一个minibatch上的损失为 0.6040, 训练准确率为 0.781
# 第8380步, 一个minibatch上的损失为 0.4251, 训练准确率为 0.875
# 第8390步, 一个minibatch上的损失为 0.5146, 训练准确率为 0.805
# 第8400步, 一个minibatch上的损失为 0.5577, 训练准确率为 0.812
# 第8410步, 一个minibatch上的损失为 0.5784, 训练准确率为 0.867
# 第8420步, 一个minibatch上的损失为 0.5609, 训练准确率为 0.797
# 第8430步, 一个minibatch上的损失为 0.5317, 训练准确率为 0.820
# 第8440步, 一个minibatch上的损失为 0.4771, 训练准确率为 0.859
# 第8450步, 一个minibatch上的损失为 0.4884, 训练准确率为 0.812
# 第8460步, 一个minibatch上的损失为 0.5915, 训练准确率为 0.797
# 第8470步, 一个minibatch上的损失为 0.4849, 训练准确率为 0.883
# 第8480步, 一个minibatch上的损失为 0.5081, 训练准确率为 0.844
# 第8490步, 一个minibatch上的损失为 0.4164, 训练准确率为 0.883
# 第8500步, 一个minibatch上的损失为 0.5367, 训练准确率为 0.828
# 第8510步, 一个minibatch上的损失为 0.5582, 训练准确率为 0.812
# 第8520步, 一个minibatch上的损失为 0.5378, 训练准确率为 0.836
# 第8530步, 一个minibatch上的损失为 0.5900, 训练准确率为 0.805
# 第8540步, 一个minibatch上的损失为 0.4884, 训练准确率为 0.875
# 第8550步, 一个minibatch上的损失为 0.6167, 训练准确率为 0.797
# 第8560步, 一个minibatch上的损失为 0.4691, 训练准确率为 0.898
# 第8570步, 一个minibatch上的损失为 0.4945, 训练准确率为 0.844
# 第8580步, 一个minibatch上的损失为 0.5680, 训练准确率为 0.805
# 第8590步, 一个minibatch上的损失为 0.7265, 训练准确率为 0.789
# 第8600步, 一个minibatch上的损失为 0.5283, 训练准确率为 0.836
# 第8610步, 一个minibatch上的损失为 0.6310, 训练准确率为 0.781
# 第8620步, 一个minibatch上的损失为 0.5497, 训练准确率为 0.844
# 第8630步, 一个minibatch上的损失为 0.5954, 训练准确率为 0.828
# 第8640步, 一个minibatch上的损失为 0.4637, 训练准确率为 0.859
# 第8650步, 一个minibatch上的损失为 0.7128, 训练准确率为 0.773
# 第8660步, 一个minibatch上的损失为 0.4183, 训练准确率为 0.898
# 第8670步, 一个minibatch上的损失为 0.5545, 训练准确率为 0.828
# 第8680步, 一个minibatch上的损失为 0.4894, 训练准确率为 0.820
# 第8690步, 一个minibatch上的损失为 0.6647, 训练准确率为 0.820
# 第8700步, 一个minibatch上的损失为 0.5189, 训练准确率为 0.852
# 第8710步, 一个minibatch上的损失为 0.5226, 训练准确率为 0.844
# 第8720步, 一个minibatch上的损失为 0.5407, 训练准确率为 0.820
# 第8730步, 一个minibatch上的损失为 0.6228, 训练准确率为 0.812
# 第8740步, 一个minibatch上的损失为 0.4917, 训练准确率为 0.859
# 第8750步, 一个minibatch上的损失为 0.6134, 训练准确率为 0.805
# 第8760步, 一个minibatch上的损失为 0.6205, 训练准确率为 0.797
# 第8770步, 一个minibatch上的损失为 0.5290, 训练准确率为 0.812
# 第8780步, 一个minibatch上的损失为 0.4870, 训练准确率为 0.852
# 第8790步, 一个minibatch上的损失为 0.4153, 训练准确率为 0.867
# 第8800步, 一个minibatch上的损失为 0.6660, 训练准确率为 0.773
# 第8810步, 一个minibatch上的损失为 0.4518, 训练准确率为 0.883
# 第8820步, 一个minibatch上的损失为 0.4941, 训练准确率为 0.859
# 第8830步, 一个minibatch上的损失为 0.5128, 训练准确率为 0.828
# 第8840步, 一个minibatch上的损失为 0.4928, 训练准确率为 0.836
# 第8850步, 一个minibatch上的损失为 0.3467, 训练准确率为 0.906
# 第8860步, 一个minibatch上的损失为 0.5607, 训练准确率为 0.859
# 第8870步, 一个minibatch上的损失为 0.4838, 训练准确率为 0.852
# 第8880步, 一个minibatch上的损失为 0.4998, 训练准确率为 0.828
# 第8890步, 一个minibatch上的损失为 0.4558, 训练准确率为 0.852
# 第8900步, 一个minibatch上的损失为 0.5383, 训练准确率为 0.797
# 第8910步, 一个minibatch上的损失为 0.4078, 训练准确率为 0.875
# 第8920步, 一个minibatch上的损失为 0.4267, 训练准确率为 0.867
# 第8930步, 一个minibatch上的损失为 0.4717, 训练准确率为 0.875
# 第8940步, 一个minibatch上的损失为 0.4342, 训练准确率为 0.859
# 第8950步, 一个minibatch上的损失为 0.6134, 训练准确率为 0.766
# 第8960步, 一个minibatch上的损失为 0.6347, 训练准确率为 0.805
# 第8970步, 一个minibatch上的损失为 0.4512, 训练准确率为 0.898
# 第8980步, 一个minibatch上的损失为 0.4316, 训练准确率为 0.875
# 第8990步, 一个minibatch上的损失为 0.4306, 训练准确率为 0.875
# 第9000步, 一个minibatch上的损失为 0.5810, 训练准确率为 0.836
# 第9010步, 一个minibatch上的损失为 0.5101, 训练准确率为 0.852
# 第9020步, 一个minibatch上的损失为 0.5685, 训练准确率为 0.820
# 第9030步, 一个minibatch上的损失为 0.5202, 训练准确率为 0.836
# 第9040步, 一个minibatch上的损失为 0.4262, 训练准确率为 0.891
# 第9050步, 一个minibatch上的损失为 0.6041, 训练准确率为 0.797
# 第9060步, 一个minibatch上的损失为 0.5025, 训练准确率为 0.859
# 第9070步, 一个minibatch上的损失为 0.4624, 训练准确率为 0.852
# 第9080步, 一个minibatch上的损失为 0.3781, 训练准确率为 0.875
# 第9090步, 一个minibatch上的损失为 0.5483, 训练准确率为 0.773
# 第9100步, 一个minibatch上的损失为 0.3789, 训练准确率为 0.898
# 第9110步, 一个minibatch上的损失为 0.5875, 训练准确率为 0.812
# 第9120步, 一个minibatch上的损失为 0.4706, 训练准确率为 0.812
# 第9130步, 一个minibatch上的损失为 0.5435, 训练准确率为 0.805
# 第9140步, 一个minibatch上的损失为 0.5130, 训练准确率为 0.883
# 第9150步, 一个minibatch上的损失为 0.4468, 训练准确率为 0.875
# 第9160步, 一个minibatch上的损失为 0.4343, 训练准确率为 0.875
# 第9170步, 一个minibatch上的损失为 0.4912, 训练准确率为 0.867
# 第9180步, 一个minibatch上的损失为 0.5020, 训练准确率为 0.844
# 第9190步, 一个minibatch上的损失为 0.5217, 训练准确率为 0.844
# 第9200步, 一个minibatch上的损失为 0.5243, 训练准确率为 0.859
# 第9210步, 一个minibatch上的损失为 0.4165, 训练准确率为 0.883
# 第9220步, 一个minibatch上的损失为 0.4838, 训练准确率为 0.867
# 第9230步, 一个minibatch上的损失为 0.4134, 训练准确率为 0.875
# 第9240步, 一个minibatch上的损失为 0.3878, 训练准确率为 0.898
# 第9250步, 一个minibatch上的损失为 0.4373, 训练准确率为 0.875
# 第9260步, 一个minibatch上的损失为 0.5755, 训练准确率为 0.836
# 第9270步, 一个minibatch上的损失为 0.5353, 训练准确率为 0.820
# 第9280步, 一个minibatch上的损失为 0.5561, 训练准确率为 0.859
# 第9290步, 一个minibatch上的损失为 0.4505, 训练准确率为 0.844
# 第9300步, 一个minibatch上的损失为 0.4632, 训练准确率为 0.883
# 第9310步, 一个minibatch上的损失为 0.4219, 训练准确率为 0.844
# 第9320步, 一个minibatch上的损失为 0.4832, 训练准确率为 0.828
# 第9330步, 一个minibatch上的损失为 0.5107, 训练准确率为 0.859
# 第9340步, 一个minibatch上的损失为 0.3197, 训练准确率为 0.930
# 第9350步, 一个minibatch上的损失为 0.4820, 训练准确率为 0.859
# 第9360步, 一个minibatch上的损失为 0.5490, 训练准确率为 0.789
# 第9370步, 一个minibatch上的损失为 0.3853, 训练准确率为 0.867
# 第9380步, 一个minibatch上的损失为 0.5324, 训练准确率为 0.820
# 第9390步, 一个minibatch上的损失为 0.5250, 训练准确率为 0.812
# 第9400步, 一个minibatch上的损失为 0.3994, 训练准确率为 0.875
# 第9410步, 一个minibatch上的损失为 0.4011, 训练准确率为 0.875
# 第9420步, 一个minibatch上的损失为 0.3406, 训练准确率为 0.898
# 第9430步, 一个minibatch上的损失为 0.5331, 训练准确率为 0.836
# 第9440步, 一个minibatch上的损失为 0.5308, 训练准确率为 0.797
# 第9450步, 一个minibatch上的损失为 0.4873, 训练准确率为 0.852
# 第9460步, 一个minibatch上的损失为 0.4290, 训练准确率为 0.859
# 第9470步, 一个minibatch上的损失为 0.4388, 训练准确率为 0.836
# 第9480步, 一个minibatch上的损失为 0.5105, 训练准确率为 0.867
# 第9490步, 一个minibatch上的损失为 0.6231, 训练准确率为 0.812
# 第9500步, 一个minibatch上的损失为 0.5034, 训练准确率为 0.852
# 第9510步, 一个minibatch上的损失为 0.4033, 训练准确率为 0.914
# 第9520步, 一个minibatch上的损失为 0.3947, 训练准确率为 0.867
# 第9530步, 一个minibatch上的损失为 0.5234, 训练准确率为 0.859
# 第9540步, 一个minibatch上的损失为 0.5563, 训练准确率为 0.852
# 第9550步, 一个minibatch上的损失为 0.4849, 训练准确率为 0.844
# 第9560步, 一个minibatch上的损失为 0.5352, 训练准确率为 0.828
# 第9570步, 一个minibatch上的损失为 0.5382, 训练准确率为 0.805
# 第9580步, 一个minibatch上的损失为 0.5647, 训练准确率为 0.828
# 第9590步, 一个minibatch上的损失为 0.5274, 训练准确率为 0.836
# 第9600步, 一个minibatch上的损失为 0.6152, 训练准确率为 0.766
# 第9610步, 一个minibatch上的损失为 0.5558, 训练准确率为 0.844
# 第9620步, 一个minibatch上的损失为 0.3662, 训练准确率为 0.883
# 第9630步, 一个minibatch上的损失为 0.3988, 训练准确率为 0.891
# 第9640步, 一个minibatch上的损失为 0.3881, 训练准确率为 0.875
# 第9650步, 一个minibatch上的损失为 0.5481, 训练准确率为 0.812
# 第9660步, 一个minibatch上的损失为 0.5050, 训练准确率为 0.812
# 第9670步, 一个minibatch上的损失为 0.5533, 训练准确率为 0.812
# 第9680步, 一个minibatch上的损失为 0.6143, 训练准确率为 0.812
# 第9690步, 一个minibatch上的损失为 0.4576, 训练准确率为 0.875
# 第9700步, 一个minibatch上的损失为 0.3599, 训练准确率为 0.906
# 第9710步, 一个minibatch上的损失为 0.3818, 训练准确率为 0.883
# 第9720步, 一个minibatch上的损失为 0.5373, 训练准确率为 0.859
# 第9730步, 一个minibatch上的损失为 0.4486, 训练准确率为 0.844
# 第9740步, 一个minibatch上的损失为 0.5311, 训练准确率为 0.836
# 第9750步, 一个minibatch上的损失为 0.5536, 训练准确率为 0.805
# 第9760步, 一个minibatch上的损失为 0.4068, 训练准确率为 0.859
# 第9770步, 一个minibatch上的损失为 0.4562, 训练准确率为 0.836
# 第9780步, 一个minibatch上的损失为 0.3902, 训练准确率为 0.891
# 第9790步, 一个minibatch上的损失为 0.5240, 训练准确率为 0.812
# 第9800步, 一个minibatch上的损失为 0.5882, 训练准确率为 0.812
# 第9810步, 一个minibatch上的损失为 0.4296, 训练准确率为 0.875
# 第9820步, 一个minibatch上的损失为 0.3699, 训练准确率为 0.898
# 第9830步, 一个minibatch上的损失为 0.5253, 训练准确率为 0.867
# 第9840步, 一个minibatch上的损失为 0.4829, 训练准确率为 0.836
# 第9850步, 一个minibatch上的损失为 0.4785, 训练准确率为 0.867
# 第9860步, 一个minibatch上的损失为 0.5202, 训练准确率为 0.852
# 第9870步, 一个minibatch上的损失为 0.3892, 训练准确率为 0.898
# 第9880步, 一个minibatch上的损失为 0.4789, 训练准确率为 0.859
# 第9890步, 一个minibatch上的损失为 0.4634, 训练准确率为 0.828
# 第9900步, 一个minibatch上的损失为 0.4863, 训练准确率为 0.820
# 第9910步, 一个minibatch上的损失为 0.3972, 训练准确率为 0.844
# 第9920步, 一个minibatch上的损失为 0.4760, 训练准确率为 0.844
# 第9930步, 一个minibatch上的损失为 0.4398, 训练准确率为 0.852
# 第9940步, 一个minibatch上的损失为 0.5379, 训练准确率为 0.828
# 第9950步, 一个minibatch上的损失为 0.4843, 训练准确率为 0.820
# 第9960步, 一个minibatch上的损失为 0.3714, 训练准确率为 0.891
# 第9970步, 一个minibatch上的损失为 0.4718, 训练准确率为 0.875
# 第9980步, 一个minibatch上的损失为 0.5322, 训练准确率为 0.805
# 第9990步, 一个minibatch上的损失为 0.4957, 训练准确率为 0.852
# 第10000步, 一个minibatch上的损失为 0.4720, 训练准确率为 0.852
# 完成训练！
# 测试准确率为  0.859375

# %% [markdown]
# ### 版权归 © 稀牛学院 所有 保留所有权利
# ![](./graphs/xiniu_neteasy.png)
